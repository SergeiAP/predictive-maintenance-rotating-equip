# %% [markdown]
# # 1. Imports

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ROOT_FOLDER = ".."
import sys
sys.path.append(ROOT_FOLDER)

# %%
import pandas as pd
import numpy as np

from pathlib import Path
import pyarrow as pa
from tqdm.autonotebook import tqdm
from datetime import datetime
import copy

from tslearn.clustering import TimeSeriesKMeans, KShape
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.feature_selection import VarianceThreshold
import tsfel

import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams

# %% [markdown]
# Custom

# %%
from src.visualization.plot_stats import plot_corr_matrix, plot_grouped_hists
from src.visualization.plot_plotly import plot_time_series
from src.visualization.plot_knn_pca import plot_elbow, plot_and_get_pca, plot_tsne
from src.features.detect_peaks import get_signals_peaks
from src.features.get_fft_psd import get_fft_values, get_psd_values

# %% [markdown]
# ### Constants

# %%
SEED = 42

DATA_RAW_PATH = Path("../data/raw")
DATA_INTER_PATH = Path("../data/interim")
DATA_PROC_PATH = Path("../data/processed")
PIC_EXPLORATORY_PATH = Path("../reports/figures/exploratory")

TRAIN_DATA = "X_train.parquet"
TRAIN_DATA_Y = "y_train.parquet"
METAINFO = "messages.xlsx"
METAINFO_SAVE = "metainfo"
FLOAT_TYPE = "float32"
SAVE_EXT = ".csv"

FREQ = 10
NAN_VAL = -1
NEG_VAL = -1
NAN_MARK = 3
NEG_MARK = 1
MAX_MARK = 2
NEG_TRESH = 0

GROUP_FREQ = '1Min'
GROUP_FUNC = 'mean'
GROUP_FUNC_Y = 'median'

# %%
EQUIP_NAMES = ["ЭКСГАУСТЕР "+ str(i) for i in range(4, 10)]
FEATURE_NAMES= [
    'ТОК РОТОРА 1', 'ТОК РОТОРА 2', 'ТОК СТАТОРА', 
    'ДАВЛЕНИЕ МАСЛА В СИСТЕМЕ',
    'ТЕМПЕРАТУРА ПОДШИПНИКА НА ОПОРЕ 1', 'ТЕМПЕРАТУРА ПОДШИПНИКА НА ОПОРЕ 2', 'ТЕМПЕРАТУРА ПОДШИПНИКА НА ОПОРЕ 3', 'ТЕМПЕРАТУРА ПОДШИПНИКА НА ОПОРЕ 4',
    'ТЕМПЕРАТУРА МАСЛА В СИСТЕМЕ', 'ТЕМПЕРАТУРА МАСЛА В МАСЛОБЛОКЕ',
    'ВИБРАЦИЯ НА ОПОРЕ 1', 'ВИБРАЦИЯ НА ОПОРЕ 2', 'ВИБРАЦИЯ НА ОПОРЕ 3', 'ВИБРАЦИЯ НА ОПОРЕ 4', 
    'ВИБРАЦИЯ НА ОПОРЕ 3. ПРОДОЛЬНАЯ.', 'ВИБРАЦИЯ НА ОПОРЕ 4. ПРОДОЛЬНАЯ.',
    ]
NAME_EXCLUSION = ('ЭКСГАУСТЕР 4. ТОК РОТОРА 2', 'ЭКСГАУСТЕР 4. ТОК РОТОРА2')
DATETIME_COL = "DT"

# %%
current_stator_cols = ['ток ротора 1', 'ток ротора 2', 'ток статора']
pressure_oil = ['давление масла в системе']
bearing_temp = ['температура подшипника на опоре 1', 'температура подшипника на опоре 2', 'температура подшипника на опоре 3', 'температура подшипника на опоре 4']
oil_temp = ['температура масла в системе', 'температура масла в маслоблоке']
vibration_x = ['вибрация на опоре 1', 'вибрация на опоре 2', 'вибрация на опоре 3', 'вибрация на опоре 4']
vibration_y = ['вибрация на опоре 3. продольная.', 'вибрация на опоре 4. продольная.']

# %% [markdown]
# Plot params

# %%
# Matplotlib params
rcParams['figure.figsize'] = 24, 8
plt.set_loglevel('WARNING')

SMALL_SIZE = 16
MEDIUM_SIZE = 18
BIGGER_SIZE = 20

rcParams['font.size'] = SMALL_SIZE          # controls default text sizes
rcParams['axes.titlesize'] = SMALL_SIZE     # fontsize of the axes title
rcParams['axes.labelsize'] = MEDIUM_SIZE    # fontsize of the x and y labels
rcParams['xtick.labelsize'] = SMALL_SIZE    # fontsize of the tick labels
rcParams['ytick.labelsize'] = SMALL_SIZE    # fontsize of the tick labels
rcParams['legend.fontsize'] = SMALL_SIZE    # legend fontsize
rcParams['figure.titlesize'] = BIGGER_SIZE  # fontsize of the figure title

sns.set_theme()
BASE_CONTEXT = 'fivethirtyeight'

# Plot
SHOW_ROWS = 600

# See palette
PALETTE = sns.color_palette()
print(PALETTE.as_hex())
# Out:
# ['#4c72b0', '#dd8452', '#55a868', '#c44e52', '#8172b3', '#937860', '#da8bc3', '#8c8c8c', '#ccb974', '#64b5cd']

# %% [markdown]
# # 2. Data uploading

# %%
def df_describe_info(df: pd.DataFrame,
                     percentiles: list[float] =[.002, .01, .05, .5, .95, .99],
                     ) -> None:
    display(df.info(show_counts=True))
    display(df.describe(percentiles=percentiles))
    print(f"NaNs portion: {sum(df.isna().any(axis=1)) / len(df):.3f}")

# %% [markdown]
# ## 2.1. Train x

# %%
df_train_cols = [eq_name + ". " + feature_name for eq_name in EQUIP_NAMES for feature_name in FEATURE_NAMES]
df_train_cols = [NAME_EXCLUSION[1] if item == NAME_EXCLUSION[0] else item for item in df_train_cols]

df_train_schema = pa.schema([(name, "float32") for name in df_train_cols] + [(DATETIME_COL, pa.timestamp('s'))])

# %% [markdown]
# ### Common info

# %%
df_train = pd.read_parquet(DATA_RAW_PATH / TRAIN_DATA, schema=df_train_schema)
display(df_train.info(show_counts=True))
df_train.set_index(DATETIME_COL, drop=True, inplace=True)
df_train.rename({NAME_EXCLUSION[1]: NAME_EXCLUSION[0]}, axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ArrowMemoryError                          Traceback (most recent call last)
# Cell In[333], line 1
# ----> 1 df_train = pd.read_parquet(DATA_RAW_PATH / TRAIN_DATA, schema=df_train_schema)
#       2 display(df_train.info(show_counts=True))
#       3 df_train.set_index(DATETIME_COL, drop=True, inplace=True)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\parquet.py:509, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, **kwargs)
#     506     use_nullable_dtypes = False
#     507 check_dtype_backend(dtype_backend)
# --> 509 return impl.read(
#     510     path,
#     511     columns=columns,
#     512     storage_options=storage_options,
#     513     use_nullable_dtypes=use_nullable_dtypes,
#     514     dtype_backend=dtype_backend,
#     515     **kwargs,
#     516 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\parquet.py:227, in PyArrowImpl.read(self, path, columns, use_nullable_dtypes, dtype_backend, storage_options, **kwargs)
#     220 path_or_handle, handles, kwargs["filesystem"] = _get_path_or_handle(
#     221     path,
#     222     kwargs.pop("filesystem", None),
#     223     storage_options=storage_options,
#     224     mode="rb",
#     225 )
#     226 try:
# --> 227     pa_table = self.api.parquet.read_table(
#     228         path_or_handle, columns=columns, **kwargs
#     229     )
#     230     result = pa_table.to_pandas(**to_pandas_kwargs)
#     232     if manager == "array":
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\pyarrow\parquet\core.py:3002, in read_table(source, columns, use_threads, metadata, schema, use_pandas_metadata, read_dictionary, memory_map, buffer_size, partitioning, filesystem, filters, use_legacy_dataset, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit)
#    2991         # TODO test that source is not a directory or a list
#    2992         dataset = ParquetFile(
#    2993             source, metadata=metadata, read_dictionary=read_dictionary,
#    2994             memory_map=memory_map, buffer_size=buffer_size,
#    (...)
#    2999             thrift_container_size_limit=thrift_container_size_limit,
#    3000         )
# -> 3002     return dataset.read(columns=columns, use_threads=use_threads,
#    3003                         use_pandas_metadata=use_pandas_metadata)
#    3005 warnings.warn(
#    3006     "Passing 'use_legacy_dataset=True' to get the legacy behaviour is "
#    3007     "deprecated as of pyarrow 8.0.0, and the legacy implementation will "
#    3008     "be removed in a future version.",
#    3009     FutureWarning, stacklevel=2)
#    3011 if ignore_prefixes is not None:
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\pyarrow\parquet\core.py:2630, in _ParquetDatasetV2.read(self, columns, use_threads, use_pandas_metadata)
#    2622         index_columns = [
#    2623             col for col in _get_pandas_index_columns(metadata)
#    2624             if not isinstance(col, dict)
#    2625         ]
#    2626         columns = (
#    2627             list(columns) + list(set(index_columns) - set(columns))
#    2628         )
# -> 2630 table = self._dataset.to_table(
#    2631     columns=columns, filter=self._filter_expression,
#    2632     use_threads=use_threads
#    2633 )
#    2635 # if use_pandas_metadata, restore the pandas metadata (which gets
#    2636 # lost if doing a specific `columns` selection in to_table)
#    2637 if use_pandas_metadata:
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\pyarrow\_dataset.pyx:556, in pyarrow._dataset.Dataset.to_table()
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\pyarrow\_dataset.pyx:3638, in pyarrow._dataset.Scanner.to_table()
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\pyarrow\error.pxi:144, in pyarrow.lib.pyarrow_internal_check_status()
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\pyarrow\error.pxi:117, in pyarrow.lib.check_status()
#
# ArrowMemoryError: malloc of size 72623040 failed

# %% [markdown]
# ### Separate info by eqiupment

# %%
df_train_dict = {}
for equip_name in EQUIP_NAMES:
    df_train_dict[equip_name.lower()] = df_train[df_train.columns[df_train.columns.str.startswith(equip_name)]]
    df_train_dict[equip_name.lower()].columns = df_train_dict[equip_name.lower()].columns.str[len(EQUIP_NAMES[0] + ". "):].str.lower()
    df_train_dict[equip_name.lower()].index.name = df_train_dict[equip_name.lower()].index.name.lower()

# %% [markdown]
# Lowercase column names etc.

# %%
EQUIP_NAMES = [equip_name.lower() for equip_name in EQUIP_NAMES]
FEATURE_NAMES = [feature_name.lower() for feature_name in FEATURE_NAMES]
DATETIME_COL = DATETIME_COL.lower()

# %% [markdown]
# Dataset timerange.

# %%
df_train_start_end = (df_train_dict[EQUIP_NAMES[0]].index.min(), df_train_dict[EQUIP_NAMES[0]].index.max())
df_train_shape = df_train_dict[EQUIP_NAMES[0]].shape
print("Date period: ", df_train_start_end)
print("Shape: ", df_train_shape)
# Out:
# Date period:  (Timestamp('2019-01-16 13:21:00'), Timestamp('2021-12-31 23:59:50'))
# Shape:  (9335034, 16)

# %% [markdown]
# ### Separate info by eqiupment

# %%
test_eqip = EQUIP_NAMES[0]

# %% [markdown]
# Time frequency

# %%
dt_diff = (df_train_dict[test_eqip].index[1:] - df_train_dict[test_eqip].index[:-1]).seconds
print("Mean, min, max of datetime column:", np.mean(dt_diff), np.min(dt_diff), np.max(dt_diff))
# Out:
# Mean, min, max of datetime column: 10.0 10 10

# %%
# for equip_name in EQUIP_NAMES:
#     df_train_dict[equip_name] = df_train_dict[equip_name].dropna(how="all")

# %% [markdown]
# ### Analyse one of the equipment

# %%
df_describe_info(df_train_dict[test_eqip])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9335034 entries, 2019-01-16 13:21:00 to 2021-12-31 23:59:50
# Data columns (total 16 columns):
#  #   Column                             Non-Null Count    Dtype
# ---  ------                             --------------    -----
#  0   ток ротора 1                       8502866 non-null  float32
#  1   ток ротора 2                       8496869 non-null  float32
#  2   ток статора                        8864552 non-null  float32
#  3   давление масла в системе           8635520 non-null  float32
#  4   температура подшипника на опоре 1  6425379 non-null  float32
#  5   температура подшипника на опоре 2  6322328 non-null  float32
#  6   температура подшипника на опоре 3  6365231 non-null  float32
#  7   температура подшипника на опоре 4  6417749 non-null  float32
#  8   температура масла в системе        6375755 non-null  float32
#  9   температура масла в маслоблоке     6322877 non-null  float32
#  10  вибрация на опоре 1                8532819 non-null  float32
#  11  вибрация на опоре 2                8407650 non-null  float32
#  12  вибрация на опоре 3                8519049 non-null  float32
#  13  вибрация на опоре 4                8915882 non-null  float32
#  14  вибрация на опоре 3. продольная.   8857177 non-null  float32
#  15  вибрация на опоре 4. продольная.   8498674 non-null  float32
# dtypes: float32(16)
# memory usage: 641.0 MB
# None
#        ток ротора 1  ток ротора 2   ток статора  давление масла в системе  \
# count  8.502866e+06  8.496869e+06  8.864552e+06              8.635520e+06
# mean   2.856738e+02  2.859001e+02  2.571010e+02              1.310709e+02
# std    6.387723e+01  6.339924e+01  4.500917e+01              2.662698e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00              0.000000e+00
# 0.2%   6.076389e-01  6.076389e-01  1.736111e-01              0.000000e+00
# 1%     1.502893e+00  1.502893e+00  3.559028e-01              1.543210e-01
# 5%     2.278125e+02  2.278220e+02  2.415800e+02              1.008100e+02
# 50%    2.740419e+02  2.742780e+02  2.618400e+02              1.292800e+02
# 95%    3.812457e+02  3.812703e+02  2.837480e+02              1.702780e+02
# 99%    3.983150e+02  3.983150e+02  2.929840e+02              1.855300e+02
# max    4.088904e+02  4.088904e+02  6.000000e+03              4.000000e+02
#
#        температура подшипника на опоре 1  температура подшипника на опоре 2  \
# count                       6.425379e+06                       6.322328e+06
# mean                        4.745253e+01                       4.616409e+01
# std                         7.173366e+00                       7.068939e+00
# min                        -1.000000e+02                      -1.000000e+02
# 0.2%                        6.490133e+00                       1.055000e+01
# 1%                          1.379000e+01                       1.785000e+01
# 5%                          3.651000e+01                       3.695771e+01
# 50%                         4.867601e+01                       4.624000e+01
# 95%                         5.579713e+01                       5.678868e+01
# 99%                         5.814079e+01                       6.076390e+01
# max                         4.869347e+02                       7.634020e+01
#
#        температура подшипника на опоре 3  температура подшипника на опоре 4  \
# count                       6.365231e+06                       6.417749e+06
# mean                        4.263668e+01                       4.491410e+01
# std                         6.088381e+00                       6.002651e+00
# min                         0.000000e+00                      -1.620000e+00
# 0.2%                        8.112663e+00                       8.842802e+00
# 1%                          1.623000e+01                       1.776675e+01
# 5%                          3.326000e+01                       3.651000e+01
# 50%                         4.344785e+01                       4.551207e+01
# 95%                         5.029855e+01                       5.210136e+01
# 99%                         5.321910e+01                       5.480559e+01
# max                         5.800558e+01                       6.085000e+01
#
#        температура масла в системе  температура масла в маслоблоке  \
# count                 6.375755e+06                    6.322877e+06
# mean                  3.632390e+01                    4.200555e+01
# std                   8.192476e+00                    5.553409e+00
# min                  -8.100000e-01                    0.000000e+00
# 0.2%                  8.112663e+00                    1.217000e+01
# 1%                    1.136000e+01                    2.109294e+01
# 5%                    1.793802e+01                    3.326000e+01
# 50%                   3.812955e+01                    4.234812e+01
# 95%                   4.672896e+01                    4.964953e+01
# 99%                   4.981179e+01                    5.273234e+01
# max                   5.670755e+01                    5.598000e+01
#
#        вибрация на опоре 1  вибрация на опоре 2  вибрация на опоре 3  \
# count         8.532819e+06         8.407650e+06         8.519049e+06
# mean          1.273967e+00         9.407912e-01         1.179088e+00
# std           4.843087e-01         3.745172e-01         8.630037e-01
# min           0.000000e+00         0.000000e+00         0.000000e+00
# 0.2%          2.777778e-02         6.000000e-02         6.000000e-02
# 1%            5.381944e-02         9.000000e-02         8.333333e-02
# 5%            3.900000e-01         4.300000e-01         2.400000e-01
# 50%           1.360000e+00         8.619791e-01         8.603395e-01
# 95%           2.013889e+00         1.670000e+00         2.780000e+00
# 99%           2.220000e+00         1.921875e+00         3.666088e+00
# max           2.405000e+01         1.000000e+02         1.000000e+02
#
#        вибрация на опоре 4  вибрация на опоре 3. продольная.  \
# count         8.915882e+06                      8.857177e+06
# mean          1.591222e+00                      3.105385e+00
# std           3.100204e+00                      1.865003e+00
# min          -1.000000e+02                      0.000000e+00
# 0.2%          3.000000e-02                      8.000000e-02
# 1%            6.000000e-02                      9.452160e-02
# 5%            6.200000e-01                      8.940972e-01
# 50%           1.460000e+00                      2.560000e+00
# 95%           3.488619e+00                      6.790000e+00
# 99%           4.235243e+00                      8.120000e+00
# max           1.000000e+02                      2.250000e+01
#
#        вибрация на опоре 4. продольная.
# count                      8.498674e+06
# mean                       1.229493e+00
# std                        7.942830e-01
# min                        0.000000e+00
# 0.2%                       7.000000e-02
# 1%                         1.100000e-01
# 5%                         3.300000e-01
# 50%                        1.040000e+00
# 95%                        2.800000e+00
# 99%                        3.289062e+00
# max                        3.000000e+01
# NaNs portion: 0.463

# %%
display(df_train_dict[test_eqip].info(show_counts=True))
display(df_train_dict[test_eqip].describe(percentiles=[.002, .01, .05, .5, .95, .99]))
print(f"NaNs portion: {sum(df_train_dict[test_eqip].isna().any(axis=1)) / len(df_train_dict[test_eqip]):.3f}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9335034 entries, 2019-01-16 13:21:00 to 2021-12-31 23:59:50
# Data columns (total 16 columns):
#  #   Column                             Non-Null Count    Dtype
# ---  ------                             --------------    -----
#  0   ток ротора 1                       8502866 non-null  float32
#  1   ток ротора 2                       8496869 non-null  float32
#  2   ток статора                        8864552 non-null  float32
#  3   давление масла в системе           8635520 non-null  float32
#  4   температура подшипника на опоре 1  6425379 non-null  float32
#  5   температура подшипника на опоре 2  6322328 non-null  float32
#  6   температура подшипника на опоре 3  6365231 non-null  float32
#  7   температура подшипника на опоре 4  6417749 non-null  float32
#  8   температура масла в системе        6375755 non-null  float32
#  9   температура масла в маслоблоке     6322877 non-null  float32
#  10  вибрация на опоре 1                8532819 non-null  float32
#  11  вибрация на опоре 2                8407650 non-null  float32
#  12  вибрация на опоре 3                8519049 non-null  float32
#  13  вибрация на опоре 4                8915882 non-null  float32
#  14  вибрация на опоре 3. продольная.   8857177 non-null  float32
#  15  вибрация на опоре 4. продольная.   8498674 non-null  float32
# dtypes: float32(16)
# memory usage: 641.0 MB
# None
#        ток ротора 1  ток ротора 2   ток статора  давление масла в системе  \
# count  8.502866e+06  8.496869e+06  8.864552e+06              8.635520e+06
# mean   2.856738e+02  2.859001e+02  2.571010e+02              1.310709e+02
# std    6.387723e+01  6.339924e+01  4.500917e+01              2.662698e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00              0.000000e+00
# 0.2%   6.076389e-01  6.076389e-01  1.736111e-01              0.000000e+00
# 1%     1.502893e+00  1.502893e+00  3.559028e-01              1.543210e-01
# 5%     2.278125e+02  2.278220e+02  2.415800e+02              1.008100e+02
# 50%    2.740419e+02  2.742780e+02  2.618400e+02              1.292800e+02
# 95%    3.812457e+02  3.812703e+02  2.837480e+02              1.702780e+02
# 99%    3.983150e+02  3.983150e+02  2.929840e+02              1.855300e+02
# max    4.088904e+02  4.088904e+02  6.000000e+03              4.000000e+02
#
#        температура подшипника на опоре 1  температура подшипника на опоре 2  \
# count                       6.425379e+06                       6.322328e+06
# mean                        4.745253e+01                       4.616409e+01
# std                         7.173366e+00                       7.068939e+00
# min                        -1.000000e+02                      -1.000000e+02
# 0.2%                        6.490133e+00                       1.055000e+01
# 1%                          1.379000e+01                       1.785000e+01
# 5%                          3.651000e+01                       3.695771e+01
# 50%                         4.867601e+01                       4.624000e+01
# 95%                         5.579713e+01                       5.678868e+01
# 99%                         5.814079e+01                       6.076390e+01
# max                         4.869347e+02                       7.634020e+01
#
#        температура подшипника на опоре 3  температура подшипника на опоре 4  \
# count                       6.365231e+06                       6.417749e+06
# mean                        4.263668e+01                       4.491410e+01
# std                         6.088381e+00                       6.002651e+00
# min                         0.000000e+00                      -1.620000e+00
# 0.2%                        8.112663e+00                       8.842802e+00
# 1%                          1.623000e+01                       1.776675e+01
# 5%                          3.326000e+01                       3.651000e+01
# 50%                         4.344785e+01                       4.551207e+01
# 95%                         5.029855e+01                       5.210136e+01
# 99%                         5.321910e+01                       5.480559e+01
# max                         5.800558e+01                       6.085000e+01
#
#        температура масла в системе  температура масла в маслоблоке  \
# count                 6.375755e+06                    6.322877e+06
# mean                  3.632390e+01                    4.200555e+01
# std                   8.192476e+00                    5.553409e+00
# min                  -8.100000e-01                    0.000000e+00
# 0.2%                  8.112663e+00                    1.217000e+01
# 1%                    1.136000e+01                    2.109294e+01
# 5%                    1.793802e+01                    3.326000e+01
# 50%                   3.812955e+01                    4.234812e+01
# 95%                   4.672896e+01                    4.964953e+01
# 99%                   4.981179e+01                    5.273234e+01
# max                   5.670755e+01                    5.598000e+01
#
#        вибрация на опоре 1  вибрация на опоре 2  вибрация на опоре 3  \
# count         8.532819e+06         8.407650e+06         8.519049e+06
# mean          1.273967e+00         9.407912e-01         1.179088e+00
# std           4.843087e-01         3.745172e-01         8.630037e-01
# min           0.000000e+00         0.000000e+00         0.000000e+00
# 0.2%          2.777778e-02         6.000000e-02         6.000000e-02
# 1%            5.381944e-02         9.000000e-02         8.333333e-02
# 5%            3.900000e-01         4.300000e-01         2.400000e-01
# 50%           1.360000e+00         8.619791e-01         8.603395e-01
# 95%           2.013889e+00         1.670000e+00         2.780000e+00
# 99%           2.220000e+00         1.921875e+00         3.666088e+00
# max           2.405000e+01         1.000000e+02         1.000000e+02
#
#        вибрация на опоре 4  вибрация на опоре 3. продольная.  \
# count         8.915882e+06                      8.857177e+06
# mean          1.591222e+00                      3.105385e+00
# std           3.100204e+00                      1.865003e+00
# min          -1.000000e+02                      0.000000e+00
# 0.2%          3.000000e-02                      8.000000e-02
# 1%            6.000000e-02                      9.452160e-02
# 5%            6.200000e-01                      8.940972e-01
# 50%           1.460000e+00                      2.560000e+00
# 95%           3.488619e+00                      6.790000e+00
# 99%           4.235243e+00                      8.120000e+00
# max           1.000000e+02                      2.250000e+01
#
#        вибрация на опоре 4. продольная.
# count                      8.498674e+06
# mean                       1.229493e+00
# std                        7.942830e-01
# min                        0.000000e+00
# 0.2%                       7.000000e-02
# 1%                         1.100000e-01
# 5%                         3.300000e-01
# 50%                        1.040000e+00
# 95%                        2.800000e+00
# 99%                        3.289062e+00
# max                        3.000000e+01
# NaNs portion: 0.463

# %% [markdown]
# * Many NaNs - 0,463. Some parameters have more null, e.g. all temperatures
# * Also "ток статора" имеет очень высокие значения (600А), "давление масла в системе" (4 избыт. атм.?), "температура подшипника" 486 C, вибрации на опорах (на опорах 1 и 2 - выше 2, на 3 и 4 - 3,5; продольные - 3-8)
# * Negative values looks anomalies

# %% [markdown]
# NaNs in one row

# %%
print("NaNs in one row:")
for col in df_train_dict[test_eqip].columns:
    nans_count = df_train_dict[test_eqip][col].isnull().astype(int).groupby(df_train_dict[test_eqip][col].notnull().astype(int).cumsum()).sum()
    print(f"Column {col} in hours {nans_count.max() * FREQ / 60 / 60:.1f} hours and {nans_count.max()} counts")
# Out:
# NaNs in one row:
# Column ток ротора 1 in hours 232.3 hours and 83630 counts
# Column ток ротора 2 in hours 232.3 hours and 83630 counts
# Column ток статора in hours 232.3 hours and 83630 counts
# Column давление масла в системе in hours 232.3 hours and 83630 counts
# Column температура подшипника на опоре 1 in hours 232.3 hours and 83630 counts
# Column температура подшипника на опоре 2 in hours 232.3 hours and 83630 counts
# Column температура подшипника на опоре 3 in hours 232.3 hours and 83630 counts
# Column температура подшипника на опоре 4 in hours 232.3 hours and 83631 counts
# Column температура масла в системе in hours 232.3 hours and 83637 counts
# Column температура масла в маслоблоке in hours 232.3 hours and 83636 counts
# Column вибрация на опоре 1 in hours 232.3 hours and 83630 counts
# Column вибрация на опоре 2 in hours 232.3 hours and 83630 counts
# Column вибрация на опоре 3 in hours 232.3 hours and 83630 counts
# Column вибрация на опоре 4 in hours 232.3 hours and 83630 counts
# Column вибрация на опоре 3. продольная. in hours 232.3 hours and 83630 counts
# Column вибрация на опоре 4. продольная. in hours 232.3 hours and 83630 counts

# %% [markdown]
# One of the periond have NaNs during 232 hours. Without such case (when all NaNs) NaNs in row ~ 30 hours.

# %% [markdown]
# ### Separate vibration data

# %%
df_train_vib_dict = {}
for equip_name in EQUIP_NAMES:
    df_equip_ = df_train_dict[equip_name][vibration_x + vibration_y].copy()
    df_equip_[df_equip_.isnull()] = NAN_VAL
    df_equip_[df_equip_ < NEG_TRESH] = NEG_VAL
    df_train_vib_dict[equip_name] = df_equip_

# %% [markdown]
# ### Aggreagte data

# %%
for equip_name in EQUIP_NAMES:
    df_train_dict[equip_name] = df_train_dict[equip_name].groupby(pd.Grouper(freq=GROUP_FREQ)).aggregate(GROUP_FUNC)

# %% [markdown]
# Was 9335034, now 1555839 rows

# %% [markdown]
# ### Save NaN's positions and doubtful values

# %% [markdown]
# * `df_train_state_dict` - store indicators of bad values or __NaNs__
# * for `df_train_dict` - replace __NaNs__ and __negative values__

# %%
df_train_state_dict = {equip_name: pd.DataFrame(0, index=df_train_dict[equip_name].index, columns=df_train_dict[equip_name].columns, dtype=np.int8) for equip_name in EQUIP_NAMES}

for equip_name in EQUIP_NAMES:
    df_train_state_dict[equip_name][df_train_dict[equip_name].isnull()] = NAN_MARK
    df_train_state_dict[equip_name][df_train_dict[equip_name] < NEG_TRESH] = NEG_MARK
    df_train_dict[equip_name][df_train_dict[equip_name].isnull()] = NAN_VAL
    df_train_dict[equip_name][df_train_dict[equip_name] < NEG_TRESH] = NEG_VAL

# %%
df_describe_info(df_train_dict[test_eqip])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1555839 entries, 2019-01-16 13:21:00 to 2021-12-31 23:59:00
# Freq: T
# Data columns (total 16 columns):
#  #   Column                             Non-Null Count    Dtype
# ---  ------                             --------------    -----
#  0   ток ротора 1                       1555839 non-null  float32
#  1   ток ротора 2                       1555839 non-null  float32
#  2   ток статора                        1555839 non-null  float32
#  3   давление масла в системе           1555839 non-null  float32
#  4   температура подшипника на опоре 1  1555839 non-null  float32
#  5   температура подшипника на опоре 2  1555839 non-null  float32
#  6   температура подшипника на опоре 3  1555839 non-null  float32
#  7   температура подшипника на опоре 4  1555839 non-null  float32
#  8   температура масла в системе        1555839 non-null  float32
#  9   температура масла в маслоблоке     1555839 non-null  float32
#  10  вибрация на опоре 1                1555839 non-null  float32
#  11  вибрация на опоре 2                1555839 non-null  float32
#  12  вибрация на опоре 3                1555839 non-null  float32
#  13  вибрация на опоре 4                1555839 non-null  float32
#  14  вибрация на опоре 3. продольная.   1555839 non-null  float32
#  15  вибрация на опоре 4. продольная.   1555839 non-null  float32
# dtypes: float32(16)
# memory usage: 106.8 MB
# None
#        ток ротора 1  ток ротора 2   ток статора  давление масла в системе  \
# count  1.555839e+06  1.555839e+06  1.555839e+06              1.555839e+06
# mean   2.718409e+02  2.718725e+02  2.458754e+02              1.259223e+02
# std    8.388812e+01  8.384470e+01  6.798654e+01              3.657796e+01
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00             -1.000000e+00
# 0.2%  -1.000000e+00 -1.000000e+00 -1.000000e+00             -1.000000e+00
# 1%    -1.000000e+00 -1.000000e+00 -1.000000e+00             -1.000000e+00
# 5%     1.714445e+00  1.508727e+00  2.604167e-01              6.963735e-01
# 50%    2.524988e+02  2.525596e+02  2.611915e+02              1.280792e+02
# 95%    3.791037e+02  3.791037e+02  2.834238e+02              1.698699e+02
# 99%    3.979829e+02  3.979830e+02  2.927658e+02              1.852080e+02
# max    4.079844e+02  4.079844e+02  6.000000e+03              4.000000e+02
#
#        температура подшипника на опоре 1  температура подшипника на опоре 2  \
# count                       1.555839e+06                       1.555839e+06
# mean                        4.033101e+01                       3.905657e+01
# std                         1.767732e+01                       1.783024e+01
# min                        -1.000000e+00                      -1.000000e+00
# 0.2%                       -1.000000e+00                      -1.000000e+00
# 1%                         -1.000000e+00                      -1.000000e+00
# 5%                         -1.000000e+00                      -1.000000e+00
# 50%                         4.664500e+01                       4.502500e+01
# 95%                         5.517967e+01                       5.570556e+01
# 99%                         5.786679e+01                       5.949000e+01
# max                         7.796183e+01                       7.601906e+01
#
#        температура подшипника на опоре 3  температура подшипника на опоре 4  \
# count                       1.555839e+06                       1.555839e+06
# mean                        3.558645e+01                       3.798860e+01
# std                         1.615249e+01                       1.632980e+01
# min                        -1.000000e+00                      -1.000000e+00
# 0.2%                       -1.000000e+00                      -1.000000e+00
# 1%                         -1.000000e+00                      -1.000000e+00
# 5%                         -1.000000e+00                      -1.000000e+00
# 50%                         4.162172e+01                       4.379338e+01
# 95%                         4.955489e+01                       5.151500e+01
# 99%                         5.279994e+01                       5.435489e+01
# max                         5.781778e+01                       6.022539e+01
#
#        температура масла в системе  температура масла в маслоблоке  \
# count                 1.555839e+06                    1.555839e+06
# mean                  3.071867e+01                    3.500560e+01
# std                   1.475874e+01                    1.597877e+01
# min                  -1.000000e+00                   -1.000000e+00
# 0.2%                 -1.000000e+00                   -1.000000e+00
# 1%                   -1.000000e+00                   -1.000000e+00
# 5%                   -1.000000e+00                   -1.000000e+00
# 50%                   3.563001e+01                    4.084595e+01
# 95%                   4.596925e+01                    4.899301e+01
# 99%                   4.926043e+01                    5.232500e+01
# max                   5.644314e+01                    5.586775e+01
#
#        вибрация на опоре 1  вибрация на опоре 2  вибрация на опоре 3  \
# count         1.555839e+06         1.555839e+06         1.555839e+06
# mean          1.190418e+00         8.777451e-01         1.113310e+00
# std           6.087348e-01         4.851554e-01         9.194074e-01
# min          -1.000000e+00        -1.000000e+00        -1.000000e+00
# 0.2%         -1.000000e+00        -1.000000e+00        -1.000000e+00
# 1%           -1.000000e+00        -1.000000e+00        -1.000000e+00
# 5%            1.075000e-01         1.360000e-01         1.125000e-01
# 50%           1.336667e+00         8.433333e-01         8.383333e-01
# 95%           1.998587e+00         1.655000e+00         2.753940e+00
# 99%           2.212050e+00         1.906473e+00         3.644895e+00
# max           6.125000e+00         1.741667e+01         2.508250e+01
#
#        вибрация на опоре 4  вибрация на опоре 3. продольная.  \
# count         1.555839e+06                      1.555839e+06
# mean          1.596157e+00                      2.995057e+00
# std           9.636254e-01                      1.955154e+00
# min          -1.000000e+00                     -1.000000e+00
# 0.2%         -1.000000e+00                     -1.000000e+00
# 1%           -1.000000e+00                     -1.000000e+00
# 5%            1.000000e-01                      1.216667e-01
# 50%           1.428418e+00                      2.501667e+00
# 95%           3.386936e+00                      6.760000e+00
# 99%           4.034119e+00                      8.088997e+00
# max           1.070832e+01                      1.793167e+01
#
#        вибрация на опоре 4. продольная.
# count                      1.555839e+06
# mean                       1.158709e+00
# std                        8.631763e-01
# min                       -1.000000e+00
# 0.2%                      -1.000000e+00
# 1%                        -1.000000e+00
# 5%                         1.850000e-01
# 50%                        9.969457e-01
# 95%                        2.767819e+00
# 99%                        3.267162e+00
# max                        1.051667e+01
# NaNs portion: 0.000

# %%
df_describe_info(df_train_state_dict[test_eqip])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1555839 entries, 2019-01-16 13:21:00 to 2021-12-31 23:59:00
# Freq: T
# Data columns (total 16 columns):
#  #   Column                             Non-Null Count    Dtype
# ---  ------                             --------------    -----
#  0   ток ротора 1                       1555839 non-null  int8
#  1   ток ротора 2                       1555839 non-null  int8
#  2   ток статора                        1555839 non-null  int8
#  3   давление масла в системе           1555839 non-null  int8
#  4   температура подшипника на опоре 1  1555839 non-null  int8
#  5   температура подшипника на опоре 2  1555839 non-null  int8
#  6   температура подшипника на опоре 3  1555839 non-null  int8
#  7   температура подшипника на опоре 4  1555839 non-null  int8
#  8   температура масла в системе        1555839 non-null  int8
#  9   температура масла в маслоблоке     1555839 non-null  int8
#  10  вибрация на опоре 1                1555839 non-null  int8
#  11  вибрация на опоре 2                1555839 non-null  int8
#  12  вибрация на опоре 3                1555839 non-null  int8
#  13  вибрация на опоре 4                1555839 non-null  int8
#  14  вибрация на опоре 3. продольная.   1555839 non-null  int8
#  15  вибрация на опоре 4. продольная.   1555839 non-null  int8
# dtypes: int8(16)
# memory usage: 35.6 MB
# None
#        ток ротора 1  ток ротора 2   ток статора  давление масла в системе  \
# count  1.555839e+06  1.555839e+06  1.555839e+06              1.555839e+06
# mean   3.859397e-02  3.919943e-02  4.166755e-02              3.949959e-02
# std    1.926253e-01  1.940692e-01  1.998284e-01              1.947804e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00              0.000000e+00
# 0.2%   0.000000e+00  0.000000e+00  0.000000e+00              0.000000e+00
# 1%     0.000000e+00  0.000000e+00  0.000000e+00              0.000000e+00
# 5%     0.000000e+00  0.000000e+00  0.000000e+00              0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00              0.000000e+00
# 95%    0.000000e+00  0.000000e+00  0.000000e+00              0.000000e+00
# 99%    1.000000e+00  1.000000e+00  1.000000e+00              1.000000e+00
# max    1.000000e+00  1.000000e+00  1.000000e+00              1.000000e+00
#
#        температура подшипника на опоре 1  температура подшипника на опоре 2  \
# count                       1.555839e+06                       1.555839e+06
# mean                        1.341900e-01                       1.475770e-01
# std                         3.409809e-01                       3.552470e-01
# min                         0.000000e+00                       0.000000e+00
# 0.2%                        0.000000e+00                       0.000000e+00
# 1%                          0.000000e+00                       0.000000e+00
# 5%                          0.000000e+00                       0.000000e+00
# 50%                         0.000000e+00                       0.000000e+00
# 95%                         1.000000e+00                       1.000000e+00
# 99%                         1.000000e+00                       1.000000e+00
# max                         2.000000e+00                       2.000000e+00
#
#        температура подшипника на опоре 3  температура подшипника на опоре 4  \
# count                       1.555839e+06                       1.555839e+06
# mean                        1.446339e-01                       1.327528e-01
# std                         3.517314e-01                       3.394249e-01
# min                         0.000000e+00                       0.000000e+00
# 0.2%                        0.000000e+00                       0.000000e+00
# 1%                          0.000000e+00                       0.000000e+00
# 5%                          0.000000e+00                       0.000000e+00
# 50%                         0.000000e+00                       0.000000e+00
# 95%                         1.000000e+00                       1.000000e+00
# 99%                         1.000000e+00                       1.000000e+00
# max                         1.000000e+00                       2.000000e+00
#
#        температура масла в системе  температура масла в маслоблоке  \
# count                 1.555839e+06                    1.555839e+06
# mean                  1.385754e-01                    1.488265e-01
# std                   3.456834e-01                    3.559174e-01
# min                   0.000000e+00                    0.000000e+00
# 0.2%                  0.000000e+00                    0.000000e+00
# 1%                    0.000000e+00                    0.000000e+00
# 5%                    0.000000e+00                    0.000000e+00
# 50%                   0.000000e+00                    0.000000e+00
# 95%                   1.000000e+00                    1.000000e+00
# 99%                   1.000000e+00                    1.000000e+00
# max                   2.000000e+00                    1.000000e+00
#
#        вибрация на опоре 1  вибрация на опоре 2  вибрация на опоре 3  \
# count         1.555839e+06         1.555839e+06         1.555839e+06
# mean          2.725925e-02         2.721297e-02         2.761725e-02
# std           1.628379e-01         1.627035e-01         1.638736e-01
# min           0.000000e+00         0.000000e+00         0.000000e+00
# 0.2%          0.000000e+00         0.000000e+00         0.000000e+00
# 1%            0.000000e+00         0.000000e+00         0.000000e+00
# 5%            0.000000e+00         0.000000e+00         0.000000e+00
# 50%           0.000000e+00         0.000000e+00         0.000000e+00
# 95%           0.000000e+00         0.000000e+00         0.000000e+00
# 99%           1.000000e+00         1.000000e+00         1.000000e+00
# max           1.000000e+00         1.000000e+00         1.000000e+00
#
#        вибрация на опоре 4  вибрация на опоре 3. продольная.  \
# count         1.555839e+06                      1.555839e+06
# mean          2.848688e-02                      2.391957e-02
# std           1.711731e-01                      1.527987e-01
# min           0.000000e+00                      0.000000e+00
# 0.2%          0.000000e+00                      0.000000e+00
# 1%            0.000000e+00                      0.000000e+00
# 5%            0.000000e+00                      0.000000e+00
# 50%           0.000000e+00                      0.000000e+00
# 95%           0.000000e+00                      0.000000e+00
# 99%           1.000000e+00                      1.000000e+00
# max           2.000000e+00                      1.000000e+00
#
#        вибрация на опоре 4. продольная.
# count                      1.555839e+06
# mean                       2.739808e-02
# std                        1.632404e-01
# min                        0.000000e+00
# 0.2%                       0.000000e+00
# 1%                         0.000000e+00
# 5%                         0.000000e+00
# 50%                        0.000000e+00
# 95%                        0.000000e+00
# 99%                        1.000000e+00
# max                        1.000000e+00
# NaNs portion: 0.000

# %%
display(df_train_state_dict[test_eqip].info(show_counts=True))
display(df_train_state_dict[test_eqip].describe(percentiles=[.002, .01, .05, .5, .95, .99]))
print(f"NaNs portion: {sum(df_train_state_dict[test_eqip].isna().any(axis=1)) / len(df_train_state_dict[test_eqip]):.3f}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1555839 entries, 2019-01-16 13:21:00 to 2021-12-31 23:59:00
# Freq: T
# Data columns (total 16 columns):
#  #   Column                             Non-Null Count    Dtype
# ---  ------                             --------------    -----
#  0   ток ротора 1                       1555839 non-null  int8
#  1   ток ротора 2                       1555839 non-null  int8
#  2   ток статора                        1555839 non-null  int8
#  3   давление масла в системе           1555839 non-null  int8
#  4   температура подшипника на опоре 1  1555839 non-null  int8
#  5   температура подшипника на опоре 2  1555839 non-null  int8
#  6   температура подшипника на опоре 3  1555839 non-null  int8
#  7   температура подшипника на опоре 4  1555839 non-null  int8
#  8   температура масла в системе        1555839 non-null  int8
#  9   температура масла в маслоблоке     1555839 non-null  int8
#  10  вибрация на опоре 1                1555839 non-null  int8
#  11  вибрация на опоре 2                1555839 non-null  int8
#  12  вибрация на опоре 3                1555839 non-null  int8
#  13  вибрация на опоре 4                1555839 non-null  int8
#  14  вибрация на опоре 3. продольная.   1555839 non-null  int8
#  15  вибрация на опоре 4. продольная.   1555839 non-null  int8
# dtypes: int8(16)
# memory usage: 35.6 MB
# None
#        ток ротора 1  ток ротора 2   ток статора  давление масла в системе  \
# count  1.555839e+06  1.555839e+06  1.555839e+06              1.555839e+06
# mean   3.859397e-02  3.919943e-02  4.166755e-02              3.949959e-02
# std    1.926253e-01  1.940692e-01  1.998284e-01              1.947804e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00              0.000000e+00
# 0.2%   0.000000e+00  0.000000e+00  0.000000e+00              0.000000e+00
# 1%     0.000000e+00  0.000000e+00  0.000000e+00              0.000000e+00
# 5%     0.000000e+00  0.000000e+00  0.000000e+00              0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00              0.000000e+00
# 95%    0.000000e+00  0.000000e+00  0.000000e+00              0.000000e+00
# 99%    1.000000e+00  1.000000e+00  1.000000e+00              1.000000e+00
# max    1.000000e+00  1.000000e+00  1.000000e+00              1.000000e+00
#
#        температура подшипника на опоре 1  температура подшипника на опоре 2  \
# count                       1.555839e+06                       1.555839e+06
# mean                        1.341900e-01                       1.475770e-01
# std                         3.409809e-01                       3.552470e-01
# min                         0.000000e+00                       0.000000e+00
# 0.2%                        0.000000e+00                       0.000000e+00
# 1%                          0.000000e+00                       0.000000e+00
# 5%                          0.000000e+00                       0.000000e+00
# 50%                         0.000000e+00                       0.000000e+00
# 95%                         1.000000e+00                       1.000000e+00
# 99%                         1.000000e+00                       1.000000e+00
# max                         2.000000e+00                       2.000000e+00
#
#        температура подшипника на опоре 3  температура подшипника на опоре 4  \
# count                       1.555839e+06                       1.555839e+06
# mean                        1.446339e-01                       1.327528e-01
# std                         3.517314e-01                       3.394249e-01
# min                         0.000000e+00                       0.000000e+00
# 0.2%                        0.000000e+00                       0.000000e+00
# 1%                          0.000000e+00                       0.000000e+00
# 5%                          0.000000e+00                       0.000000e+00
# 50%                         0.000000e+00                       0.000000e+00
# 95%                         1.000000e+00                       1.000000e+00
# 99%                         1.000000e+00                       1.000000e+00
# max                         1.000000e+00                       2.000000e+00
#
#        температура масла в системе  температура масла в маслоблоке  \
# count                 1.555839e+06                    1.555839e+06
# mean                  1.385754e-01                    1.488265e-01
# std                   3.456834e-01                    3.559174e-01
# min                   0.000000e+00                    0.000000e+00
# 0.2%                  0.000000e+00                    0.000000e+00
# 1%                    0.000000e+00                    0.000000e+00
# 5%                    0.000000e+00                    0.000000e+00
# 50%                   0.000000e+00                    0.000000e+00
# 95%                   1.000000e+00                    1.000000e+00
# 99%                   1.000000e+00                    1.000000e+00
# max                   2.000000e+00                    1.000000e+00
#
#        вибрация на опоре 1  вибрация на опоре 2  вибрация на опоре 3  \
# count         1.555839e+06         1.555839e+06         1.555839e+06
# mean          2.725925e-02         2.721297e-02         2.761725e-02
# std           1.628379e-01         1.627035e-01         1.638736e-01
# min           0.000000e+00         0.000000e+00         0.000000e+00
# 0.2%          0.000000e+00         0.000000e+00         0.000000e+00
# 1%            0.000000e+00         0.000000e+00         0.000000e+00
# 5%            0.000000e+00         0.000000e+00         0.000000e+00
# 50%           0.000000e+00         0.000000e+00         0.000000e+00
# 95%           0.000000e+00         0.000000e+00         0.000000e+00
# 99%           1.000000e+00         1.000000e+00         1.000000e+00
# max           1.000000e+00         1.000000e+00         1.000000e+00
#
#        вибрация на опоре 4  вибрация на опоре 3. продольная.  \
# count         1.555839e+06                      1.555839e+06
# mean          2.848688e-02                      2.391957e-02
# std           1.711731e-01                      1.527987e-01
# min           0.000000e+00                      0.000000e+00
# 0.2%          0.000000e+00                      0.000000e+00
# 1%            0.000000e+00                      0.000000e+00
# 5%            0.000000e+00                      0.000000e+00
# 50%           0.000000e+00                      0.000000e+00
# 95%           0.000000e+00                      0.000000e+00
# 99%           1.000000e+00                      1.000000e+00
# max           2.000000e+00                      1.000000e+00
#
#        вибрация на опоре 4. продольная.
# count                      1.555839e+06
# mean                       2.739808e-02
# std                        1.632404e-01
# min                        0.000000e+00
# 0.2%                       0.000000e+00
# 1%                         0.000000e+00
# 5%                         0.000000e+00
# 50%                        0.000000e+00
# 95%                        0.000000e+00
# 99%                        1.000000e+00
# max                        1.000000e+00
# NaNs portion: 0.000

# %% [markdown]
# ### Save data

# %%
# for equip_name in EQUIP_NAMES:
#     df_train_dict[equip_name].to_csv(DATA_INTER_PATH / (equip_name + "_train" + SAVE_EXT))
# for equip_name in EQUIP_NAMES:
#     df_train_state_dict[equip_name].to_csv(DATA_INTER_PATH / (equip_name + "_train_idx" + SAVE_EXT))

# %% [markdown]
# ## 2.2. Train y

# %%
Y_NAMES = [
    'Y_ЭКСГАУСТЕР А/М №9_ЗАПОРНАЯ АРМАТУРА ЭКСГАУСТЕРА №9',
    'Y_ЭКСГАУСТЕР А/М №9_МАСЛОСТАНЦИЯ ЖИДКОЙ СМАЗКИ ЭКСГ. №9',
    'Y_ЭКСГАУСТЕР А/М №9_ЭЛЕКТРОАППАРАТУРА ЭКСГ. №9',
    'Y_ЭКСГАУСТЕР А/М №9_КЛ1 ТР№9 ДО ЭД ЭКСГАУСТЕРА №9',
    'Y_ЭКСГАУСТЕР А/М №9_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №9',
    'Y_ЭКСГАУСТЕР А/М №9_КОРПУС ЭКСГ. №9',
    'Y_ЭКСГАУСТЕР А/М №9_РЕДУКТОР ГАЗ. ЗАДВИЖКИ ЭКСГ. №9',
    'Y_ЭКСГАУСТЕР А/М №9_МАСЛООХЛАДИТЕЛЬ  М-05-1 ЭКСГ. №9',
    'Y_ЭКСГАУСТЕР А/М №9_ЭЛ/ДВИГАТЕЛЬ ГАЗ. ЗАДВИЖКИ ЭКСГ. №9',
    'Y_ЭКСГАУСТЕР А/М №9_ЭЛЕКТРООБОРУДОВАНИЯ ЭКСГАУСТЕРА №9',
    'Y_ЭКСГАУСТЕР А/М №9_ПОДШИПНИК ОПОРНО-УПОРНЫЙ ЭКСГ. №9',
    'Y_ЭКСГАУСТЕР А/М №9_РОТОР ЭКСГ. №9',
    'Y_ЭКСГАУСТЕР А/М №9_ТР-Р ТМ-6300-10/6 ЭКСГ. №9',
    'Y_ЭКСГАУСТЕР А/М №9_ПОДШИПНИК ОПОРНЫЙ ЭКСГ. №9',
    'Y_ЭКСГАУСТЕР А/М №9_МАСЛОНАСОС РАБОЧИЙ ЭКСГ. №9',
    'Y_ЭКСГАУСТЕР А/М №9_ПОДШИПНИК ОПОРНЫЙ №2',
    'Y_ЭКСГАУСТЕР А/М №9_ГСМ ЭКСГ. №9',
    'Y_ЭКСГАУСТЕР А/М №9_КОЖУХ МУФТЫ ЭКСГ. №9',
    'Y_ЭКСГАУСТЕР А/М №9_ПОДШИПНИК ОПОРНЫЙ №1',
    'Y_ЭКСГАУСТЕР А/М №9_ЗАДВИЖКА ЭКСГ. №9',
    'Y_ЭКСГАУСТЕР А/М №9_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№9 Т.1',
    'Y_ЭКСГАУСТЕР А/М №9_МАСЛОПРОВОДЫ ЭКСГАУСТЕРА №9',
    'Y_ЭКСГАУСТЕР А/М №9_ТИРИСТОРНЫЙ ВОЗБУДИТЕЛЬ ТВ-400 ЭКСГ9 ВУ1',
    'Y_ЭКСГАУСТЕР А/М №9_МЕТРАН-100 ДАТЧИКИ ДАВЛЕНИЯ ЭКСГ.№9',
    'Y_ЭКСГАУСТЕР А/М №9_ТСМТ-101-010-50М-80 ТЕРМОПРЕОБР.МАСЛО',
    'Y_ЭКСГАУСТЕР А/М №9_ТСМТ-101-010-50М-400 ТЕРМОПР.ПОДШ.Т.1',
    'Y_ЭКСГАУСТЕР А/М №9_ЭКСГАУСТЕР А/М №9',
    'Y_ЭКСГАУСТЕР А/М №9_ДВИГАТЕЛЬ ПУСКОВОГО МАСЛОНАСОСА ЭКСГ. №9',
    'Y_ЭКСГАУСТЕР А/М №5_МАСЛООХЛАДИТЕЛЬ  М-05-1 ЭКСГ. №5',
    'Y_ЭКСГАУСТЕР А/М №5_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №5',
    'Y_ЭКСГАУСТЕР А/М №5_КОРПУС ЭКСГ. №5',
    'Y_ЭКСГАУСТЕР А/М №5_ЗАДВИЖКА ЭКСГ. №5',
    'Y_ЭКСГАУСТЕР А/М №5_ПОДШИПНИК ОПОРНЫЙ ЭКСГ. №5',
    'Y_ЭКСГАУСТЕР А/М №5_ПОДШИПНИК ОПОРНЫЙ №2',
    'Y_ЭКСГАУСТЕР А/М №5_ПОДШИПНИК ОПОРНО-УПОРНЫЙ ЭКСГ. №5',
    'Y_ЭКСГАУСТЕР А/М №5_МАСЛОНАСОС ШЕСТЕРЕНЧАТЫЙ (РЕЗ.) ЭКСГ. №5',
    'Y_ЭКСГАУСТЕР А/М №5_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№5 Т.1',
    'Y_ЭКСГАУСТЕР А/М №5_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№5 Т.3',
    'Y_ЭКСГАУСТЕР А/М №5_ЭЛЕКТРООБОРУДОВАНИЯ ЭКСГАУСТЕРА №5',
    'Y_ЭКСГАУСТЕР А/М №5_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№5 Т.2',
    'Y_ЭКСГАУСТЕР А/М №5_ПОДШИПНИК ОПОРНЫЙ №1',
    'Y_ЭКСГАУСТЕР А/М №5_РЕДУКТОР ГАЗ. ЗАДВИЖКИ ЭКСГ. №5',
    'Y_ЭКСГАУСТЕР А/М №5_ТИРИСТ. ВОЗБУДИТЕЛЬ ВТ-РЭМ-400 ЭКСГ5 ВУ1',
    'Y_ЭКСГАУСТЕР А/М №5_ЗАПОРНАЯ АРМАТУРА ЭКСГАУСТЕРА №5',
    'Y_ЭКСГАУСТЕР А/М №5_МАСЛОПРОВОДЫ ЭКСГАУСТЕРА №5',
    'Y_ЭКСГАУСТЕР А/М №5_ГСМ ЭКСГ. №5',
    'Y_ЭКСГАУСТЕР А/М №5_ЭКСГАУСТЕР А/М №5',
    'Y_ЭКСГАУСТЕР А/М №5_ТСМТ-101-010-50М-80 ТЕРМОПРЕОБР.МАСЛО',
    'Y_ЭКСГАУСТЕР А/М №5_ТР-Р ТМ-4000-10/6 ЭКСГ. №5',
    'Y_ЭКСГАУСТЕР А/М №5_КЛ1 ТР№5 ДО ЭД ЭКСГАУСТЕРА №5',
    'Y_ЭКСГАУСТЕР А/М №5_КЛ2 ТР№5 ДО ЭД ЭКСГАУСТЕРА №5',
    'Y_ЭКСГАУСТЕР А/М №5_МАСЛОНАСОС РАБОЧИЙ ЭКСГ. №5',
    'Y_ЭКСГАУСТЕР А/М №5_РОТОР ЭКСГ. №5',
    'Y_ЭКСГАУСТЕР А/М №5_МЕТРАН-100 ДАТЧИКИ ДАВЛЕНИЯ ЭКСГ.№5',
    'Y_ЭКСГАУСТЕР А/М №5_ДВИГАТЕЛЬ ПУСКОВОГО МАСЛОНАСОСА ЭКСГ. №5',
    'Y_ЭКСГАУСТЕР А/М №5_ГАЗОВАЯ ЗАДВИЖКА ЭКСГАУСТЕРА А/М №5',
    'Y_ЭКСГАУСТЕР А/М №5_КОЖУХ МУФТЫ ЭКСГ. №5',
    'Y_ЭКСГАУСТЕР А/М №5_ТИРИСТ. ВОЗБУДИТЕЛЬ ВТ-РЭМ-400 ЭКСГ5 ВУ2',
    'Y_ЭКСГАУСТЕР А/М №5_ТСМТ-101-010-50М-400 ТЕРМОПР.ПОДШ.Т.2',
    'Y_ЭКСГАУСТЕР А/М №5_ДВИГАТЕЛЬ РЕЗЕРВНОГО МАСЛОНАСОСА ЭКСГ.№5',
    'Y_ЭКСГАУСТЕР А/М №5_ТСМТ-101-010-50М-200 ТЕРМОПР.ПОДШ.Т.3',
    'Y_ЭКСГАУСТЕР А/М №5_ЭКСГАУСТЕР Н-8000 А/М №5',
    'Y_ЭКСГАУСТЕР А/М №8_РОТОР ЭКСГ. №8',
    'Y_ЭКСГАУСТЕР А/М №8_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №8',
    'Y_ЭКСГАУСТЕР А/М №8_КОРПУС ЭКСГ. №8',
    'Y_ЭКСГАУСТЕР А/М №8_РЕДУКТОР ГАЗ. ЗАДВИЖКИ ЭКСГ. №8',
    'Y_ЭКСГАУСТЕР А/М №8_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№8 Т.3',
    'Y_ЭКСГАУСТЕР А/М №8_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№8 Т.4',
    'Y_ЭКСГАУСТЕР А/М №8_ЭЛ/ДВИГАТЕЛЬ ГАЗ. ЗАДВИЖКИ ЭКСГ. №8',
    'Y_ЭКСГАУСТЕР А/М №8_МАСЛООХЛАДИТЕЛЬ  М-05-1 ЭКСГ. №8',
    'Y_ЭКСГАУСТЕР А/М №8_ТИРИСТОРНЫЙ ВОЗБУДИТЕЛЬ СПВД-М10-400-5',
    'Y_ЭКСГАУСТЕР А/М №8_КЛ2 ТР№8 ДО ЭД ЭКСГАУСТЕРА №8',
    'Y_ЭКСГАУСТЕР А/М №8_КЛ1 ТР№8 ДО ЭД ЭКСГАУСТЕРА №8',
    'Y_ЭКСГАУСТЕР А/М №8_ТСМТ-101-010-50М-400 ТЕРМОПР.ПОДШ.Т.2',
    'Y_ЭКСГАУСТЕР А/М №8_КОЖУХ МУФТЫ ЭКСГ. №8',
    'Y_ЭКСГАУСТЕР А/М №8_ГСМ ЭКСГ. №8',
    'Y_ЭКСГАУСТЕР А/М №8_ПОДШИПНИК ОПОРНЫЙ №2',
    'Y_ЭКСГАУСТЕР А/М №8_ЭКСГАУСТЕР А/М №8',
    'Y_ЭКСГАУСТЕР А/М №8_ЗАПОРНАЯ АРМАТУРА ЭКСГАУСТЕРА №8',
    'Y_ЭКСГАУСТЕР А/М №8_ТСМТ-101-010-50М-200 ТЕРМОПР.ПОДШ.Т.4',
    'Y_ЭКСГАУСТЕР А/М №8_МАСЛЯНЫЙ ФИЛЬТР ЭКСГАУСТЕРА №8',
    'Y_ЭКСГАУСТЕР А/М №8_ТИРИСТОРНЫЙ ВОЗБУДИТЕЛЬ ТВ-400 ЭКСГ8 ВУ1',
    'Y_ЭКСГАУСТЕР А/М №8_ПОДШИПНИК ОПОРНЫЙ №1',
    'Y_ЭКСГАУСТЕР А/М №8_ЭЛЕКТРООБОРУДОВАНИЯ ЭКСГАУСТЕРА №8',
    'Y_ЭКСГАУСТЕР А/М №8_ПОДШИПНИК ОПОРНЫЙ ЭКСГ. №8',
    'Y_ЭКСГАУСТЕР А/М №8_ЗАДВИЖКА ЭКСГ. №8',
    'Y_ЭКСГАУСТЕР А/М №8_МАСЛОНАСОС РАБОЧИЙ ЭКСГ. №8',
    'Y_ЭКСГАУСТЕР А/М №8_МАСЛОНАСОС ШЕСТЕРЕНЧАТЫЙ (РЕЗ.) ЭКСГ. №8',
    'Y_ЭКСГАУСТЕР А/М №8_МАСЛОНАСОС ШЕСТЕРЕНЧАТЫЙ (ПУСК.) ЭКСГ.№8',
    'Y_ЭКСГАУСТЕР А/М №8_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№8 Т.2',
    'Y_ЭКСГАУСТЕР А/М №8_ТР-Р ТМ-6300-10/6 ЭКСГ. №8',
    'Y_ЭКСГАУСТЕР А/М №8_ПОДШИПНИК ОПОРНО-УПОРНЫЙ ЭКСГ. №8',
    'Y_ЭКСГАУСТЕР А/М №8_МАСЛОПРОВОДЫ ЭКСГАУСТЕРА №8',
    'Y_ЭКСГАУСТЕР А/М №4_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №4',
    'Y_ЭКСГАУСТЕР А/М №4_ПОДШИПНИК ОПОРНЫЙ ЭКСГ. №4',
    'Y_ЭКСГАУСТЕР А/М №4_УЛИТА ЭКСГ. №4',
    'Y_ЭКСГАУСТЕР А/М №4_РЕДУКТОР ГАЗ. ЗАДВИЖКИ ЭКСГ. №4',
    'Y_ЭКСГАУСТЕР А/М №4_МАСЛОНАСОС РАБОЧИЙ ЭКСГ. №4',
    'Y_ЭКСГАУСТЕР А/М №4_ЭЛЕКТРОАППАРАТУРА ЭКСГ. №4',
    'Y_ЭКСГАУСТЕР А/М №4_ПОДШИПНИК ОПОРНЫЙ №2 ЭКСГ. №4',
    'Y_ЭКСГАУСТЕР А/М №4_ЗАДВИЖКА ЭКСГ. №4',
    'Y_ЭКСГАУСТЕР А/М №4_ГСМ ЭКСГ. №4',
    'Y_ЭКСГАУСТЕР А/М №4_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№4 Т.1',
    'Y_ЭКСГАУСТЕР А/М №4_ТСМТ-101-010-50М-400 ТЕРМОПР.ПОДШ.Т.1',
    'Y_ЭКСГАУСТЕР А/М №4_РОТОР ЭКСГ. №4',
    'Y_ЭКСГАУСТЕР А/М №4_МАСЛООХЛАДИТЕЛЬ  М-05-1 ЭКСГ. №4',
    'Y_ЭКСГАУСТЕР А/М №4_ПОДШИПНИК ОПОРНО-УПОРНЫЙ ЭКСГ. №4',
    'Y_ЭКСГАУСТЕР А/М №4_ЭКСГАУСТЕР А/М №4',
    'Y_ЭКСГАУСТЕР А/М №4_ЗАП. И РЕГ. АРМАТУРА ЭКСГ.№4',
    'Y_ЭКСГАУСТЕР А/М №4_ПОДШИПНИК ОПОРНЫЙ №1 ЭКСГ. №4',
    'Y_ЭКСГАУСТЕР А/М №4_ЭЛ/ДВИГАТЕЛЬ ГАЗ. ЗАДВИЖКИ ЭКСГ. №4',
    'Y_ЭКСГАУСТЕР А/М №4_КЛ1 ТР№4 ДО ЭД ЭКСГАУСТЕРА №4',
    'Y_ЭКСГАУСТЕР А/М №4_КЛ2 ТР№4 ДО ЭД ЭКСГАУСТЕРА №4',
    'Y_ЭКСГАУСТЕР А/М №4_ТР-Р ТМ-4000-10/6 ЭКСГ. №4',
    'Y_ЭКСГАУСТЕР А/М №4_ТИРИСТ. ВОЗБУДИТЕЛЬ ВТ-РЭМ-400 ЭКСГ4 ВУ1',
    'Y_ЭКСГАУСТЕР А/М №4_МАСЛОПРОВОДЫ ЭКСГ №4',
    'Y_ЭКСГАУСТЕР А/М №7_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №7',
    'Y_ЭКСГАУСТЕР А/М №7_КОРПУС ЭКСГ. №7',
    'Y_ЭКСГАУСТЕР А/М №7_ПОДШИПНИК ОПОРНЫЙ №1',
    'Y_ЭКСГАУСТЕР А/М №7_ЗАДВИЖКА ЭКСГ. №7',
    'Y_ЭКСГАУСТЕР А/М №7_ПОДШИПНИК ОПОРНЫЙ №2',
    'Y_ЭКСГАУСТЕР А/М №7_РОТОР ЭКСГ. №7',
    'Y_ЭКСГАУСТЕР А/М №7_ПОДШИПНИК ОПОРНО-УПОРНЫЙ ЭКСГ. №7',
    'Y_ЭКСГАУСТЕР А/М №7_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№7 Т.3',
    'Y_ЭКСГАУСТЕР А/М №7_РЕДУКТОР ГАЗ. ЗАДВИЖКИ ЭКСГ. №7',
    'Y_ЭКСГАУСТЕР А/М №7_ТСМТ-101-010-50М-80 ТЕРМОПРЕОБР.МАСЛО',
    'Y_ЭКСГАУСТЕР А/М №7_ПОДШИПНИК ОПОРНЫЙ ЭКСГ. №7',
    'Y_ЭКСГАУСТЕР А/М №7_ГСМ ЭКСГ. №7',
    'Y_ЭКСГАУСТЕР А/М №7_КОЖУХ МУФТЫ ЭКСГ. №7',
    'Y_ЭКСГАУСТЕР А/М №7_ЭКСГАУСТЕР А/М №7',
    'Y_ЭКСГАУСТЕР А/М №7_МАСЛОПРОВОДЫ ЭКСГАУСТЕРА №7',
    'Y_ЭКСГАУСТЕР А/М №7_МАСЛООХЛАДИТЕЛЬ  М-05-1 ЭКСГ. №7',
    'Y_ЭКСГАУСТЕР А/М №7_САПФИР 22 МДД ПЕРЕПАД ДАВЛ. НА ЦИКЛОНЕ',
    'Y_ЭКСГАУСТЕР А/М №7_ЭЛЕКТРООБОРУДОВАНИЯ ЭКСГАУСТЕРА №7',
    'Y_ЭКСГАУСТЕР А/М №7_МАСЛОНАСОС РАБОЧИЙ ЭКСГ. №7',
    'Y_ЭКСГАУСТЕР А/М №7_МАСЛОНАСОС ШЕСТЕРЕНЧАТЫЙ (ПУСК.) ЭКСГ.№7',
    'Y_ЭКСГАУСТЕР А/М №7_МАСЛЯНЫЙ ФИЛЬТР ЭКСГАУСТЕРА №7',
    'Y_ЭКСГАУСТЕР А/М №7_ТР-Р ТМ-4000-10/6 ЭКСГ. №7',
    'Y_ЭКСГАУСТЕР А/М №7_ТСМТ-101-010-50М-200 ТЕРМОПР.ПОДШ.Т.3',
    'Y_ЭКСГАУСТЕР А/М №7_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№7 Т.2',
    'Y_ЭКСГАУСТЕР А/М №7_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№7 Т.4',
    'Y_ЭКСГАУСТЕР А/М №7_ТИРИСТОРНЫЙ ВОЗБУДИТЕЛЬ ТВ-400 ЭКСГ7 ВУ1',
    'Y_ЭКСГАУСТЕР А/М №7_ТСМТ-101-010-50М-400 ТЕРМОПР.ПОДШ.Т.2',
    'Y_ЭКСГАУСТЕР А/М №7_КЛ1 ТР№7 ДО ЭД ЭКСГАУСТЕРА №7',
    'Y_ЭКСГАУСТЕР А/М №7_МЕТРАН-100 ДАТЧИКИ ДАВЛЕНИЯ ЭКСГ.№7',
    'Y_ЭКСГАУСТЕР А/М №7_РЕГУЛИРУЮЩАЯ АППАРАТУРА ЭКСГАУСТЕРА №7',
    'Y_ЭКСГАУСТЕР А/М №7_ЭЛ/ДВИГАТЕЛЬ ГАЗ. ЗАДВИЖКИ ЭКСГ. №7',
    'Y_ЭКСГАУСТЕР А/М №7_ТСМТ-101-010-50М-400 ТЕРМОПР.ПОДШ.Т.1',
    'Y_ЭКСГАУСТЕР А/М №6_ЭЛЕКТРОДВИГАТЕЛЬ ДСПУ-140-84-4 ЭКСГ. №6',
    'Y_ЭКСГАУСТЕР А/М №6_КОРПУС ЭКСГ. №6',
    'Y_ЭКСГАУСТЕР А/М №6_ЗАДВИЖКА ЭКСГ. №6',
    'Y_ЭКСГАУСТЕР А/М №6_ПОДШИПНИК ОПОРНЫЙ №2',
    'Y_ЭКСГАУСТЕР А/М №6_РЕДУКТОР ГАЗ. ЗАДВИЖКИ ЭКСГ. №6',
    'Y_ЭКСГАУСТЕР А/М №6_ПОДШИПНИК ОПОРНО-УПОРНЫЙ ЭКСГ. №6',
    'Y_ЭКСГАУСТЕР А/М №6_САПФИР 22 МДД РАЗРЕЖЕНИЕ В КОЛЛЕКТОРЕ',
    'Y_ЭКСГАУСТЕР А/М №6_МАСЛОБАК ЭКСГ. №6',
    'Y_ЭКСГАУСТЕР А/М №6_ПОДШИПНИК ОПОРНЫЙ №1',
    'Y_ЭКСГАУСТЕР А/М №6_КОЖУХ МУФТЫ ЭКСГ. №6',
    'Y_ЭКСГАУСТЕР А/М №6_РОТОР ЭКСГ. №6',
    'Y_ЭКСГАУСТЕР А/М №6_ТР-Р ТМ-4000-10/6 ЭКСГ. №6',
    'Y_ЭКСГАУСТЕР А/М №6_ЭЛЕКТРООБОРУДОВАНИЯ ЭКСГ №6',
    'Y_ЭКСГАУСТЕР А/М №6_МАСЛООХЛАДИТЕЛЬ  М-05-1 ЭКСГ. №6',
    'Y_ЭКСГАУСТЕР А/М №6_САПФИР 22 МДД ПЕРЕПАД ДАВЛ. НА ЦИКЛОНЕ',
    'Y_ЭКСГАУСТЕР А/М №6_МАСЛОНАСОС РАБОЧИЙ ЭКСГ. №6',
    'Y_ЭКСГАУСТЕР А/М №6_ГАЗОВАЯ ЗАДВИЖКА ЭКСГАУСТЕРА А/М №6',
    'Y_ЭКСГАУСТЕР А/М №6_ЭКСГАУСТЕР А/М №6',
    'Y_ЭКСГАУСТЕР А/М №6_ПОДШИПНИК ОПОРНЫЙ ЭКСГ. №6',
    'Y_ЭКСГАУСТЕР А/М №6_ТИРИСТОРНЫЙ ВОЗБУДИТЕЛЬ ТВ-400 ЭКСГ6 ВУ1',
    'Y_ЭКСГАУСТЕР А/М №6_ДВИГАТЕЛЬ ПУСКОВОГО МАСЛОНАСОСА ЭКСГ. №6',
    'Y_ЭКСГАУСТЕР А/М №6_МАСЛОНАСОС ШЕСТЕРЕНЧАТЫЙ (ПУСК.) ЭКСГ.№6',
    'Y_ЭКСГАУСТЕР А/М №6_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№6 Т.3',
    'Y_ЭКСГАУСТЕР А/М №6_МАСЛОПРОВОДЫ ЭКСГ №6',
    'Y_ЭКСГАУСТЕР А/М №6_КЛ1 ТР№6 ДО ЭД ЭКСГАУСТЕРА №6',
    'Y_ЭКСГАУСТЕР А/М №6_КЛ2 ТР№6 ДО ЭД ЭКСГАУСТЕРА №6',
    'Y_ЭКСГАУСТЕР А/М №6_ВК 310С ВИБРОПРЕОБРАЗОВАТЕЛЬ ЭКСГ.№6 Т.2',
]
len(Y_NAMES)
# Out:
# 175

# %%
NAMES_TO_DEL_Y = [' ЭКСГАУСТЕРА', ' ЭКСГ.', ' №{}', '№{}']
EQUIP_NAMES_PREFIX_Y = [name.format(i) for name in NAMES_TO_DEL_Y for i in range(4, 10)]
EQUIP_NAMES_Y = ['Y_ЭКСГАУСТЕР А/М №'+ str(i) for i in range(4, 10)]

# %%
df_train_y_schema = pa.schema([(name, "int8") for name in Y_NAMES] + [(DATETIME_COL.upper(), pa.timestamp('s'))])

# %% [markdown]
# ### Common info

# %%
df_train_y = pd.read_parquet(DATA_RAW_PATH / TRAIN_DATA_Y, schema=df_train_y_schema)
display(df_train_y.info(show_counts=True))
df_train_y.set_index(DATETIME_COL.upper(), drop=True, inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9335034 entries, 0 to 9335033
# Columns: 176 entries, Y_ЭКСГАУСТЕР А/М №9_ЗАПОРНАЯ АРМАТУРА ЭКСГАУСТЕРА №9 to DT
# dtypes: datetime64[s](1), int8(175)
# memory usage: 1.6 GB
# None

# %% [markdown]
# ### Separate info by eqiupment

# %%
df_train_y_dict = {}
df_train_y_cols_dict = {}

for equip_name_y, equip_name in zip(EQUIP_NAMES_Y, EQUIP_NAMES):
    df_train_y_dict[equip_name] = df_train_y[df_train_y.columns[df_train_y.columns.str.startswith(equip_name_y)]]
    df_train_y_dict[equip_name].columns = df_train_y_dict[equip_name].columns.str[len(EQUIP_NAMES_Y[0] + "_"):].str.replace('|'.join(EQUIP_NAMES_PREFIX_Y), '', regex=True).str.lower()
    df_train_y_dict[equip_name].index.name = df_train_y_dict[equip_name].index.name.lower()
    df_train_y_dict[equip_name] = df_train_y_dict[equip_name].loc[:, (df_train_y_dict[equip_name] == 0).all(axis=0)]
    df_train_y_cols_dict[equip_name] = df_train_y_dict[equip_name].columns.to_list()

# %% [markdown]
# Dataset timerange.

# %%
df_train_y_start_end = (df_train_y_dict[EQUIP_NAMES[0]].index.min(), df_train_y_dict[EQUIP_NAMES[0]].index.max())
df_train_y_shape = df_train_y_dict[EQUIP_NAMES[0]].shape
print("Date period: ", df_train_y_start_end)
print("Shape: ", df_train_y_shape)
# Out:
# Date period:  (Timestamp('2019-01-16 13:21:00'), Timestamp('2021-12-31 23:59:50'))
# Shape:  (9335034, 1)

# %%
df_describe_info(df_train_y_dict[test_eqip])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9335034 entries, 2019-01-16 13:21:00 to 2021-12-31 23:59:50
# Data columns (total 1 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   маслопроводы  9335034 non-null  int8
# dtypes: int8(1)
# memory usage: 80.1 MB
# None
#        маслопроводы
# count     9335034.0
# mean            0.0
# std             0.0
# min             0.0
# 0.2%            0.0
# 1%              0.0
# 5%              0.0
# 50%             0.0
# 95%             0.0
# 99%             0.0
# max             0.0
# NaNs portion: 0.000

# %%
for equip_name in EQUIP_NAMES:
    df_train_y_dict[equip_name] = df_train_y_dict[equip_name].groupby(pd.Grouper(freq=GROUP_FREQ)).aggregate(GROUP_FUNC_Y)

df_describe_info(df_train_y_dict[test_eqip])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1555839 entries, 2019-01-16 13:21:00 to 2021-12-31 23:59:00
# Freq: T
# Data columns (total 1 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   маслопроводы  1555839 non-null  float64
# dtypes: float64(1)
# memory usage: 23.7 MB
# None
#        маслопроводы
# count     1555839.0
# mean            0.0
# std             0.0
# min             0.0
# 0.2%            0.0
# 1%              0.0
# 5%              0.0
# 50%             0.0
# 95%             0.0
# 99%             0.0
# max             0.0
# NaNs portion: 0.000

# %%
# for equip_name in EQUIP_NAMES:
#     df_train_y_dict[equip_name].to_csv(DATA_INTER_PATH / (equip_name + "_y" + SAVE_EXT))

# %% [markdown]
# ## 2.3. Metainformation

# %%
EQUIP_NAMES_META = {equip_name_y[len('Y_'):]: equip_name for equip_name_y, equip_name in zip(EQUIP_NAMES_Y, EQUIP_NAMES)}
FAILURE_PART_COL = 'название_тех_места'
DESCRIPTION_COL = 'описание'
EQUIP_NAME = 'имя_машины'
FAILURE_TYPE_COL = 'вид_сообщения'
PLANNED_COL = 'текст_группы_кодов'
FAILURE_LASTS = "длительность"


START_END_FAILURE_DATES = ['дата_начала_неисправности', 'дата_устранения_неисправности']
PLANNED_CODES = {
    'технические плановые': 0, 
    'технические неплановые': 1,
    'технологические плановые': 0, 
    'технологические неплановые': 1, 
    'внешние организации': 1
}
FAILURES_CODES = {"shutdown": "M1", "malfunction": "M3"}

# %%
df_meta = pd.read_excel(DATA_RAW_PATH / METAINFO, index_col=None)
df_meta.columns = df_meta.columns.str.lower()
df_describe_info(df_meta)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   unnamed: 0                     981 non-null    int64
#  1   машина                         981 non-null    object
#  2   имя_машины                     981 non-null    object
#  3   тех_место                      981 non-null    object
#  4   название_тех_места             981 non-null    object
#  5   вид_сообщения                  981 non-null    object
#  6   описание                       981 non-null    object
#  7   дата_начала_неисправности      981 non-null    datetime64[ns]
#  8   дата_устранения_неисправности  851 non-null    datetime64[ns]
#  9   текст_группы_кодов             83 non-null     object
# dtypes: datetime64[ns](2), int64(1), object(7)
# memory usage: 76.8+ KB
# None
#         unnamed: 0      дата_начала_неисправности  \
# count   981.000000                            981
# mean   1183.237513  2020-07-02 17:11:04.968399616
# min     390.000000            2019-01-21 00:00:00
# 0.2%    391.960000     2019-01-21 15:27:51.680000
# 1%      400.800000     2019-01-27 10:58:40.400000
# 5%      459.000000            2019-02-25 13:38:04
# 50%    1115.000000            2020-06-26 14:41:04
# 95%    2103.000000            2021-11-09 23:46:00
# 99%    2147.200000     2021-12-20 18:06:20.400000
# max    2159.000000            2021-12-29 16:27:02
# std     540.892914                            NaN
#
#        дата_устранения_неисправности
# count                            851
# mean   2020-07-28 03:07:27.599294976
# min              2019-01-22 00:00:00
# 0.2%             2019-01-26 06:28:06
# 1%               2019-02-04 10:50:50
# 5%               2019-03-19 14:19:19
# 50%              2020-07-27 00:00:00
# 95%              2021-10-18 12:00:00
# 99%              2021-12-20 06:53:35
# max              2021-12-30 00:00:00
# std                              NaN
# NaNs portion: 0.915

# %%
df_meta[FAILURE_PART_COL] = df_meta[FAILURE_PART_COL].str.replace('|'.join(EQUIP_NAMES_PREFIX_Y), '', regex=True).str.lower()
df_meta.drop("unnamed: 0", axis=1, inplace=True)
df_meta[EQUIP_NAME].replace(EQUIP_NAMES_META, inplace=True)

# %% [markdown]
# ### Explore

# %%
# Explore specific equipment and dates
test_eqip = "эксгаустер 5" # "эксгаустер 6"
data_filter = df_train_y_dict[test_eqip].index >= "2021-12-28 12:23:00"

print("Оборудование в ремонте:")
display(df_train_y_dict[test_eqip].loc[data_filter, (df_train_y_dict[test_eqip][data_filter] > 0).all(axis=0)])
# Out:
# Оборудование в ремонте:
# Empty DataFrame
# Columns: []
# Index: [2021-12-28 12:23:00, 2021-12-28 12:24:00, 2021-12-28 12:25:00, 2021-12-28 12:26:00, 2021-12-28 12:27:00, 2021-12-28 12:28:00, 2021-12-28 12:29:00, 2021-12-28 12:30:00, 2021-12-28 12:31:00, 2021-12-28 12:32:00, 2021-12-28 12:33:00, 2021-12-28 12:34:00, 2021-12-28 12:35:00, 2021-12-28 12:36:00, 2021-12-28 12:37:00, 2021-12-28 12:38:00, 2021-12-28 12:39:00, 2021-12-28 12:40:00, 2021-12-28 12:41:00, 2021-12-28 12:42:00, 2021-12-28 12:43:00, 2021-12-28 12:44:00, 2021-12-28 12:45:00, 2021-12-28 12:46:00, 2021-12-28 12:47:00, 2021-12-28 12:48:00, 2021-12-28 12:49:00, 2021-12-28 12:50:00, 2021-12-28 12:51:00, 2021-12-28 12:52:00, 2021-12-28 12:53:00, 2021-12-28 12:54:00, 2021-12-28 12:55:00, 2021-12-28 12:56:00, 2021-12-28 12:57:00, 2021-12-28 12:58:00, 2021-12-28 12:59:00, 2021-12-28 13:00:00, 2021-12-28 13:01:00, 2021-12-28 13:02:00, 2021-12-28 13:03:00, 2021-12-28 13:04:00, 2021-12-28 13:05:00, 2021-12-28 13:06:00, 2021-12-28 13:07:00, 2021-12-28 13:08:00, 2021-12-28 13:09:00, 2021-12-28 13:10:00, 2021-12-28 13:11:00, 2021-12-28 13:12:00, 2021-12-28 13:13:00, 2021-12-28 13:14:00, 2021-12-28 13:15:00, 2021-12-28 13:16:00, 2021-12-28 13:17:00, 2021-12-28 13:18:00, 2021-12-28 13:19:00, 2021-12-28 13:20:00, 2021-12-28 13:21:00, 2021-12-28 13:22:00, 2021-12-28 13:23:00, 2021-12-28 13:24:00, 2021-12-28 13:25:00, 2021-12-28 13:26:00, 2021-12-28 13:27:00, 2021-12-28 13:28:00, 2021-12-28 13:29:00, 2021-12-28 13:30:00, 2021-12-28 13:31:00, 2021-12-28 13:32:00, 2021-12-28 13:33:00, 2021-12-28 13:34:00, 2021-12-28 13:35:00, 2021-12-28 13:36:00, 2021-12-28 13:37:00, 2021-12-28 13:38:00, 2021-12-28 13:39:00, 2021-12-28 13:40:00, 2021-12-28 13:41:00, 2021-12-28 13:42:00, 2021-12-28 13:43:00, 2021-12-28 13:44:00, 2021-12-28 13:45:00, 2021-12-28 13:46:00, 2021-12-28 13:47:00, 2021-12-28 13:48:00, 2021-12-28 13:49:00, 2021-12-28 13:50:00, 2021-12-28 13:51:00, 2021-12-28 13:52:00, 2021-12-28 13:53:00, 2021-12-28 13:54:00, 2021-12-28 13:55:00, 2021-12-28 13:56:00, 2021-12-28 13:57:00, 2021-12-28 13:58:00, 2021-12-28 13:59:00, 2021-12-28 14:00:00, 2021-12-28 14:01:00, 2021-12-28 14:02:00, ...]
#
# [5017 rows x 0 columns]

# %%
print("Ремонты без указания даты устранения неисправности:")
df_meta[df_meta["дата_устранения_неисправности"].isin([pd.NaT])]
# Out:
# Ремонты без указания даты устранения неисправности:
#                  машина    имя_машины                   тех_место  \
# 87   CH-AGP-AG2/009-005  эксгаустер 8  CH-AGP-AG2/009-005-002-004
# 162  CH-AGP-AG2/007-005  эксгаустер 7  CH-AGP-AG2/007-005-001-002
# 187  CH-AGP-AG2/003-005  эксгаустер 5  CH-AGP-AG2/003-005-003-002
# 197  CH-AGP-AG2/011-005  эксгаустер 9  CH-AGP-AG2/011-005-002-001
# 198  CH-AGP-AG2/011-005  эксгаустер 9  CH-AGP-AG2/011-005-001-003
# ..                  ...           ...                         ...
# 972         AA2/002-006  эксгаустер 5         AA2/002-006-003-003
# 973         AA2/001-006  эксгаустер 4         AA2/001-006-003-003
# 977         AA2/005-006  эксгаустер 8         AA2/005-006-003-002
# 978         AA2/003-006  эксгаустер 6         AA2/003-006-001-001
# 979         AA2/001-006  эксгаустер 4         AA2/001-006-001-006
#
#            название_тех_места вид_сообщения             описание  \
# 87    маслоохладитель  м-05-1            M3   греются подшипники
# 162                     ротор            M3           течь масла
# 187    редуктор газ. задвижки            M3           нет смазки
# 197        маслонасос рабочий            M3        неисправность
# 198  подшипник опорно-упорный            M3         утечка масла
# ..                        ...           ...                  ...
# 972                  задвижка            M3    Деформация кожуха
# 973                  задвижка            M3  Неисправны датчики.
# 977    редуктор газ. задвижки            M3    Смазка редуктора.
# 978                    корпус            M3              Прососы
# 979                     улита            M3              Прососы
#
#     дата_начала_неисправности дата_устранения_неисправности текст_группы_кодов
# 87        2019-04-08 21:50:44                           NaT                NaN
# 162       2019-06-18 18:31:12                           NaT                NaN
# 187       2019-08-13 16:37:54                           NaT                NaN
# 197       2019-08-21 19:32:00                           NaT                NaN
# 198       2019-08-21 19:40:37                           NaT                NaN
# ..                        ...                           ...                ...
# 972       2021-12-21 13:32:00                           NaT                NaN
# 973       2021-12-21 14:34:35                           NaT                NaN
# 977       2021-12-28 09:23:00                           NaT                NaN
# 978       2021-12-28 12:23:00                           NaT                NaN
# 979       2021-12-28 12:39:00                           NaT                NaN
#
# [130 rows x 9 columns]

# %%
print("Уникальных описаний поломок среди всех поломок:", f"{df_meta[DESCRIPTION_COL].nunique()}/{len(df_meta)}")
# Out:
# Уникальных описаний поломок среди всех поломок: 555/981

# %%
df_meta.groupby(FAILURE_PART_COL)[EQUIP_NAME].count()
# Out:
# название_тех_места
# вк 310с вибропреобразователь т.1            4
# вк 310с вибропреобразователь т.2            6
# вк 310с вибропреобразователь т.3           10
# вк 310с вибропреобразователь т.4            3
# газовая задвижка а/м                        2
# гсм                                        24
# двигатель пускового маслонасоса             2
# задвижка                                   79
# зап. и рег. арматура                        1
# запорная арматура                           6
# кл1 тр до эд                                5
# кл2 тр до эд                                4
# кожух муфты                                20
# корпус                                    124
# маслобак                                    5
# маслонасос рабочий                         22
# маслонасос шестеренчатый (пуск.)            2
# маслонасос шестеренчатый (рез.)             3
# маслоохладитель  м-05-1                    35
# маслопроводы                                8
# маслостанция жидкой смазки                  1
# масляный фильтр                             2
# метран-100 датчики давления                 1
# подшипник опорно-упорный                   46
# подшипник опорный                          46
# подшипник опорный №1                       27
# подшипник опорный №2                       39
# редуктор газ. задвижки                     87
# ротор                                     130
# сапфир 22 мдд перепад давл. на циклоне      2
# сапфир 22 мдд разрежение в коллекторе       2
# тирист. возбудитель вт-рэм-400 ву1          7
# тирист. возбудитель вт-рэм-400 ву2          1
# тиристорный возбудитель спвд-м10-400-5      1
# тиристорный возбудитель тв-400 ву1          5
# тр-р тм-4000-10/6                          30
# тр-р тм-6300-10/6                          20
# тсмт-101-010-50м-200 термопр.подш.т.3       1
# тсмт-101-010-50м-200 термопр.подш.т.4       1
# тсмт-101-010-50м-400 термопр.подш.т.1       1
# тсмт-101-010-50м-400 термопр.подш.т.2       4
# тсмт-101-010-50м-80 термопреобр.масло       6
# улита                                      30
# эксгаустер а/м                              9
# эл/двигатель газ. задвижки                  4
# электроаппаратура                           8
# электродвигатель дспу-140-84-4             89
# электрооборудования                        16
# Name: имя_машины, dtype: int64

# %%
df_meta[PLANNED_COL] = df_meta[PLANNED_COL].str.lower().replace(PLANNED_CODES)

# %% [markdown]
# ___

# %%
df_meta[df_meta[EQUIP_NAME] == test_eqip]
# Out:
#                  машина    имя_машины                   тех_место  \
# 2           AA2/002-006  эксгаустер 5         AA2/002-006-002-004
# 3    CH-AGP-AG2/003-005  эксгаустер 5  CH-AGP-AG2/003-005-002-004
# 4    CH-AGP-AG2/003-005  эксгаустер 5  CH-AGP-AG2/003-005-002-004
# 8    CH-AGP-AG2/003-005  эксгаустер 5  CH-AGP-AG2/003-005-001-005
# 19   CH-AGP-AG2/003-005  эксгаустер 5  CH-AGP-AG2/003-005-001-005
# ..                  ...           ...                         ...
# 959         AA2/002-006  эксгаустер 5     AA2/002-006-001-005-003
# 966         AA2/002-006  эксгаустер 5         AA2/002-006-001-010
# 972         AA2/002-006  эксгаустер 5         AA2/002-006-003-003
# 974         AA2/002-006  эксгаустер 5     AA2/002-006-001-005-001
# 975         AA2/002-006  эксгаустер 5         AA2/002-006-001-009
#
#                      название_тех_места вид_сообщения  \
# 2               маслоохладитель  м-05-1            M3
# 3               маслоохладитель  м-05-1            M3
# 4               маслоохладитель  м-05-1            M3
# 8        электродвигатель дспу-140-84-4            M3
# 19       электродвигатель дспу-140-84-4            M3
# ..                                  ...           ...
# 959      электродвигатель дспу-140-84-4            M3
# 966  тирист. возбудитель вт-рэм-400 ву2            M1
# 972                            задвижка            M3
# 974                подшипник опорный №1            M1
# 975  тирист. возбудитель вт-рэм-400 ву1            M3
#
#                                      описание дата_начала_неисправности  \
# 2    менять прокладку на подачу воды в охлади       2019-01-21 15:35:26
# 3    менять прокладку на подачу воды в охлади       2019-01-21 16:33:00
# 4    менять прокладку на подачу воды в охлади       2019-01-21 16:36:01
# 8                              искрение щетки       2019-01-27 10:45:52
# 19                             искрение щеток       2019-02-04 09:25:00
# ..                                        ...                       ...
# 959                    Требуется замена щёток       2021-12-12 11:27:00
# 966      остановка эксг. №5 (сработал АВ ВУ2)       2021-12-16 03:38:44
# 972                         Деформация кожуха       2021-12-21 13:32:00
# 974      остановка эксг. №5 (температура т.1)       2021-12-22 17:29:58
# 975       Неисправность возбудителя экс-ра 5.       2021-12-23 11:44:00
#
#     дата_устранения_неисправности  текст_группы_кодов
# 2             2019-01-23 11:00:00                 NaN
# 3             2019-01-22 00:00:00                 NaN
# 4             2019-06-04 15:35:26                 NaN
# 8             2019-01-27 12:31:11                 NaN
# 19            2019-02-04 10:50:50                 NaN
# ..                            ...                 ...
# 959                           NaT                 NaN
# 966           2021-12-16 03:56:47                 1.0
# 972                           NaT                 NaN
# 974           2021-12-22 17:36:59                 1.0
# 975           2021-12-23 17:00:00                 NaN
#
# [199 rows x 9 columns]

# %%
df_meta[FAILURE_LASTS] = df_meta[START_END_FAILURE_DATES[1]] - df_meta[START_END_FAILURE_DATES[0]]
failure_parts_wo_end = df_meta[df_meta[START_END_FAILURE_DATES[1]].isna()][FAILURE_PART_COL].unique()
failure_parts_mean = df_meta[df_meta[FAILURE_PART_COL].isin(failure_parts_wo_end)].groupby(FAILURE_PART_COL)[FAILURE_LASTS].mean().to_dict()
failure_parts_mean['кл2 тр до эд'] = failure_parts_mean['кл1 тр до эд']
df_meta[FAILURE_LASTS] = df_meta[[FAILURE_PART_COL, FAILURE_LASTS]].set_index(FAILURE_PART_COL, drop=True)[FAILURE_LASTS].fillna(value=failure_parts_mean).values
df_meta.loc[df_meta[START_END_FAILURE_DATES[1]].isna(), START_END_FAILURE_DATES[1]] = df_meta.loc[df_meta[START_END_FAILURE_DATES[1]].isna(), START_END_FAILURE_DATES[0]] + df_meta[FAILURE_LASTS]
df_meta[START_END_FAILURE_DATES[1]] = df_meta[START_END_FAILURE_DATES[1]].round('1s')

# %%
# df_meta.to_csv(DATA_PROC_PATH / ("metainfo" + SAVE_EXT))

# %% [markdown]
# # 3. EDA

# %%
df_meta[(df_meta[EQUIP_NAME] == test_eqip) & (df_meta[FAILURE_TYPE_COL] == FAILURES_CODES['malfunction'])].head(5)
# Out:
#                 машина    имя_машины                   тех_место  \
# 15  CH-AGP-AG2/005-005  эксгаустер 6  CH-AGP-AG2/005-005-001-005
# 25  CH-AGP-AG2/005-005  эксгаустер 6  CH-AGP-AG2/005-005-001-001
# 44  CH-AGP-AG2/005-005  эксгаустер 6  CH-AGP-AG2/005-005-003-003
# 45         AA2/003-006  эксгаустер 6     AA2/003-006-001-012-002
# 46  CH-AGP-AG2/005-005  эксгаустер 6  CH-AGP-AG2/005-005-003-003
#
#                 название_тех_места вид_сообщения  \
# 15  электродвигатель дспу-140-84-4            M3
# 25                          корпус            M3
# 44                        задвижка            M3
# 45            подшипник опорный №2            M3
# 46                        задвижка            M3
#
#                               описание дата_начала_неисправности  \
# 15  износ подшипников, обмотки статора       2019-01-30 05:30:12
# 25      износ уплотнения разъема улиты       2019-02-07 10:00:35
# 44        клинит задвижку при закрытии       2019-02-13 19:05:46
# 45                          течь масла       2019-02-25 00:00:00
# 46                         нет колпака       2019-02-25 13:02:18
#
#    дата_устранения_неисправности  текст_группы_кодов
# 15           2019-01-30 16:30:50                 NaN
# 25           2019-03-19 00:00:00                 NaN
# 44           2019-03-11 00:00:00                 NaN
# 45           2019-03-06 00:00:00                 NaN
# 46           2019-07-01 00:00:00                 NaN

# %%
df_meta[(df_meta[EQUIP_NAME] == test_eqip) & (df_meta[FAILURE_TYPE_COL] == FAILURES_CODES['shutdown'])]
# Out:
#                  машина    имя_машины                   тех_место  \
# 121  CH-AGP-AG2/005-005  эксгаустер 6  CH-AGP-AG2/005-005-003-003
# 123         AA2/003-006  эксгаустер 6         AA2/003-006-003-003
# 344  CH-AGP-AG2/005-005  эксгаустер 6  CH-AGP-AG2/005-005-003-003
# 350  CH-AGP-AG2/005-005  эксгаустер 6  CH-AGP-AG2/005-005-003-003
# 622  CH-AGP-AG2/005-005  эксгаустер 6      CH-AGP-AG2/005-005-003
# 738  CH-AGP-AG2/005-005  эксгаустер 6  CH-AGP-AG2/005-005-003-003
# 740         AA2/003-006  эксгаустер 6                 AA2/003-006
# 741  CH-AGP-AG2/005-005  эксгаустер 6  CH-AGP-AG2/005-005-003-003
#
#        название_тех_места вид_сообщения  \
# 121              задвижка            M1
# 123              задвижка            M1
# 344              задвижка            M1
# 350              задвижка            M1
# 622  газовая задвижка а/м            M1
# 738              задвижка            M1
# 740        эксгаустер а/м            M1
# 741              задвижка            M1
#
#                                     описание дата_начала_неисправности  \
# 121            упала задвижка на эксгаустере       2019-05-01 16:29:38
# 123            упала задвижка на эксгаустере       2019-05-01 19:18:04
# 344   остановка эксгаустера №6 (обрыв гайки)       2020-01-16 06:18:04
# 350  остановка эксгаустера №6 (монтаж гайки)       2020-01-17 10:09:38
# 622   выпуск аглопыли из газового коллектора       2020-12-02 17:10:12
# 738         остановка эк-ра №6 (обрыв гайки)       2021-04-16 13:23:07
# 740                         Согласованное ТО       2021-04-17 06:06:56
# 741         остановка эк-ра №6 (обрыв штока)       2021-04-18 18:58:57
#
#     дата_устранения_неисправности  текст_группы_кодов
# 121           2019-05-01 19:18:04                 1.0
# 123           2019-05-01 19:18:04                 1.0
# 344           2020-01-16 08:12:18                 1.0
# 350           2020-01-17 13:19:04                 1.0
# 622           2020-12-02 17:27:14                 0.0
# 738           2021-04-16 18:40:46                 1.0
# 740           2021-04-17 06:27:58                 0.0
# 741           2021-04-18 23:22:29                 1.0

# %%
df_train_dict[test_eqip].columns
# Out:
# Index(['ток ротора 1', 'ток ротора 2', 'ток статора',
#        'давление масла в системе', 'температура подшипника на опоре 1',
#        'температура подшипника на опоре 2',
#        'температура подшипника на опоре 3',
#        'температура подшипника на опоре 4', 'температура масла в системе',
#        'температура масла в маслоблоке', 'вибрация на опоре 1',
#        'вибрация на опоре 2', 'вибрация на опоре 3', 'вибрация на опоре 4',
#        'вибрация на опоре 3. продольная.', 'вибрация на опоре 4. продольная.'],
#       dtype='object')

# %%
visual_eqip = "эксгаустер 6" # test_eqip
visula_dates = ('2021-03-15 00:00:00', '2021-04-30 00:00:00') # ('2021-03-15 00:00:00', '2021-04-30 00:00:00') ('2021-04-01 00:00:00', '2021-04-30 00:00:00') ('2019-05-01 00:00:00', '2019-06-01 00:00:00')

plot_position = [0.05, 0.95]
y_plots = [current_stator_cols, pressure_oil, bearing_temp + oil_temp, vibration_x + vibration_y]
y_axis_names = ['current_v', 'pressure_pa', 'temp_c', 'vib_µm']
y_axis_map_names = [f"y{i}" for i in range(1, len(y_plots)+1)]
y_places = [0, 0.05, 0.95, 1.00]
colors = plt.get_cmap('rainbow', 20)
smooth_window = 10

savepath_plotly = PIC_EXPLORATORY_PATH / f"{visual_eqip}_{visula_dates[0].replace(':', '-')}_{visula_dates[1].replace(':', '-')}.html"
titles_plotly = {"title_text": f"Анализ работы агрегата {test_eqip} за {visula_dates[0]}-{visula_dates[1]}",
                 "xaxis_title": DATETIME_COL}

# %%
df_to_visual = df_train_dict[visual_eqip].copy()
df_to_visual = df_to_visual[(df_to_visual.index >= visula_dates[0]) & (df_to_visual.index <= visula_dates[1])]
if smooth_window > 0:
    df_to_visual = df_to_visual.rolling(smooth_window).mean()

plot_time_series(df_to_visual, y_axis_map_names, y_plots, y_axis_names, y_places, plot_position, titles_plotly, savepath_plotly, colors)

# %%
plot_corr_matrix(df_train_dict[EQUIP_NAMES[4]])

# %%
plot_grouped_hists(df_train_dict[visual_eqip], pal=PALETTE, nbins=50)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df_equip = df_meta[df_meta[EQUIP_NAME] == visual_eqip]
df_equip[(df_equip[START_END_FAILURE_DATES[0]] >= visula_dates[0]) & (df_equip[START_END_FAILURE_DATES[0]] <= visula_dates[1])]
# Out:
#                  машина    имя_машины                       тех_место  \
# 119         AA2/003-006  эксгаустер 6             AA2/003-006-003-002
# 121  CH-AGP-AG2/005-005  эксгаустер 6      CH-AGP-AG2/005-005-003-003
# 122  CH-AGP-AG2/005-005  эксгаустер 6      CH-AGP-AG2/005-005-003-002
# 123         AA2/003-006  эксгаустер 6             AA2/003-006-003-003
# 130  CH-AGP-AG2/005-005  эксгаустер 6  CH-AGP-AG2/005-005-001-005-003
#
#                  название_тех_места вид_сообщения  \
# 119          редуктор газ. задвижки            M3
# 121                        задвижка            M1
# 122          редуктор газ. задвижки            M3
# 123                        задвижка            M1
# 130  электродвигатель дспу-140-84-4            M3
#
#                                     описание дата_начала_неисправности  \
# 119  обрыв резьбы на гайке редуктора подъема       2019-05-01 00:00:00
# 121            упала задвижка на эксгаустере       2019-05-01 16:29:38
# 122  обрыв резьбы на гайке редуктора подъема       2019-05-01 18:15:29
# 123            упала задвижка на эксгаустере       2019-05-01 19:18:04
# 130                            износ 3 щеток       2019-05-11 11:09:25
#
#     дата_устранения_неисправности  текст_группы_кодов
# 119           2019-05-22 00:00:00                 NaN
# 121           2019-05-01 19:18:04                 1.0
# 122           2019-05-22 00:00:00                 NaN
# 123           2019-05-01 19:18:04                 1.0
# 130           2019-05-16 00:00:00                 NaN

# %%
# df_equip[(df_equip[START_END_FAILURE_DATES[1]] >= '') & (df_equip[START_END_FAILURE_DATES[1]] <= '2019-05-01 16:29:38')]

# %% [markdown]
# # 4. Feature engineering

# %%
df_train_dict = {}

names = ["эксгаустер 4_train.csv", "эксгаустер 5_train.csv", "эксгаустер 6_train.csv", "эксгаустер 7_train.csv", "эксгаустер 8_train.csv", "эксгаустер 9_train.csv",]
for name in names:
    df_ = pd.read_csv(DATA_INTER_PATH / name, index_col="dt")
    df_train_dict[name[:len("эксгаустер 4")]] = df_.copy()

# %% [markdown]
# ## 4.1. kNN

# %%
TIME_ANALYSE = 120
CUT_VALUE = len(df_train_dict[test_eqip]) - int(len(df_train_dict[test_eqip]) / TIME_ANALYSE) * TIME_ANALYSE
CLUSTER_COL = "кластер_knn"


MAX_ITER = 10
FIRST_CLUSTER = 6
CLUSTERS = 10
N_JOBS = 6
N_INIT = 3
METRICS_CLUSTER = 'softdtw' # 'euclidean', 'dtw', 'softdtw'

DT_IDXS = df_train_dict[test_eqip][CUT_VALUE::TIME_ANALYSE].index

# %%
# scale to have equal distance
scaler = StandardScaler()
df_test_scaled = scaler.fit_transform(df_train_dict[test_eqip])
    
# num of examples x length of timeseries x dimensions
df_test_scaled = df_test_scaled[CUT_VALUE:]
df_test_resized = np.resize(df_test_scaled, (int(df_test_scaled.shape[0] / TIME_ANALYSE), TIME_ANALYSE, df_test_scaled.shape[1]))

df_test_resized.shape
# Out:
# (12965, 120, 16)

# %%
plot_elbow(df_test_resized, seed=SEED, metric=METRICS_CLUSTER)
# Out:
#   0%|          | 0/10 [12:09<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[560], line 1
# ----> 1 plot_elbow(df_test_resized, seed=SEED, metric=METRICS_CLUSTER)
#
# File c:\Users\parshin_sa2\Desktop\Desktop\Education\ML Advanced\proj\predictive-maintenance-rotating-equip\notebooks\..\src\visualization\plot_knn_pca.py:43, in plot_elbow(df, seed, first_cluster, clusters, n_init, max_iter, metric, n_jobs)
#      36 for k in tqdm(K):
#      37     kmeanModel = TimeSeriesKMeans(n_clusters=k,
#      38                                   metric=metric,
#      39                                   n_jobs=n_jobs,
#      40                                   max_iter=max_iter,
#      41                                   n_init=n_init,
#      42                                   random_state=seed)
# ---> 43     kmeanModel.fit(df)
#      44     distortions.append(kmeanModel.inertia_)
#      45     # silhouette_score считает насколько чисты кластеры
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\tslearn\clustering\kmeans.py:821, in TimeSeriesKMeans.fit(self, X, y)
#     819     print("Init %d" % (n_successful + 1))
#     820 n_attempts += 1
# --> 821 self._fit_one_init(X_, x_squared_norms, rs)
#     822 if self.inertia_ < min_inertia:
#     823     best_correct_centroids = self.cluster_centers_.copy()
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\tslearn\clustering\kmeans.py:690, in TimeSeriesKMeans._fit_one_init(self, X, x_squared_norms, rs)
#     688 if self.verbose:
#     689     print("%.3f" % self.inertia_, end=" --> ")
# --> 690 self._update_centroids(X)
#     692 if numpy.abs(old_inertia - self.inertia_) < self.tol:
#     693     break
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\tslearn\clustering\kmeans.py:755, in TimeSeriesKMeans._update_centroids(self, X)
#     747     self.cluster_centers_[k] = dtw_barycenter_averaging(
#     748         X=X[self.labels_ == k],
#     749         barycenter_size=None,
#    (...)
#     752         verbose=False,
#     753     )
#     754 elif self.metric == "softdtw":
# --> 755     self.cluster_centers_[k] = softdtw_barycenter(
#     756         X=X[self.labels_ == k],
#     757         max_iter=self.max_iter_barycenter,
#     758         init=self.cluster_centers_[k],
#     759         **metric_params
#     760     )
#     761 else:
#     762     self.cluster_centers_[k] = euclidean_barycenter(X=X[self.labels_ == k])
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\tslearn\barycenters\softdtw.py:109, in softdtw_barycenter(X, gamma, weights, method, tol, max_iter, init)
#     106         return _softdtw_func(Z, X_, weights, barycenter, gamma)
#     108     # The function works with vectors so we need to vectorize barycenter.
# --> 109     res = minimize(f, barycenter.ravel(), method=method, jac=True, tol=tol,
#     110                    options=dict(maxiter=max_iter, disp=False))
#     111     return res.x.reshape(barycenter.shape)
#     112 else:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\scipy\optimize\_minimize.py:623, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     620     return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     621                               **options)
#     622 elif meth == 'l-bfgs-b':
# --> 623     return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     624                             callback=callback, **options)
#     625 elif meth == 'tnc':
#     626     return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     627                          **options)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\scipy\optimize\lbfgsb.py:306, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     303     else:
#     304         iprint = disp
# --> 306 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     307                               bounds=new_bounds,
#     308                               finite_diff_rel_step=finite_diff_rel_step)
#     310 func_and_grad = sf.fun_and_grad
#     312 fortran_int = _lbfgsb.types.intvar.dtype
#
# File ~\AppData\Roaming\Python\Python310\site-packages\scipy\optimize\optimize.py:261, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     257     bounds = (-np.inf, np.inf)
#     259 # ScalarFunction caches. Reuse of fun(x) during grad
#     260 # calculation reduces overall function evaluations.
# --> 261 sf = ScalarFunction(fun, x0, args, grad, hess,
#     262                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     264 return sf
#
# File ~\AppData\Roaming\Python\Python310\site-packages\scipy\optimize\_differentiable_functions.py:140, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     137     self.f = fun_wrapped(self.x)
#     139 self._update_fun_impl = update_fun
# --> 140 self._update_fun()
#     142 # Gradient evaluation
#     143 if callable(grad):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\scipy\optimize\_differentiable_functions.py:233, in ScalarFunction._update_fun(self)
#     231 def _update_fun(self):
#     232     if not self.f_updated:
# --> 233         self._update_fun_impl()
#     234         self.f_updated = True
#
# File ~\AppData\Roaming\Python\Python310\site-packages\scipy\optimize\_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.update_fun()
#     136 def update_fun():
# --> 137     self.f = fun_wrapped(self.x)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\scipy\optimize\_differentiable_functions.py:134, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     130 self.nfev += 1
#     131 # Send a copy because the user may overwrite it.
#     132 # Overwriting results in undefined behaviour because
#     133 # fun(self.x) will change self.x, with the two no longer linked.
# --> 134 return fun(np.copy(x), *args)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\scipy\optimize\optimize.py:74, in MemoizeJac.__call__(self, x, *args)
#      72 def __call__(self, x, *args):
#      73     """ returns the the function value """
# ---> 74     self._compute_if_needed(x, *args)
#      75     return self._value
#
# File ~\AppData\Roaming\Python\Python310\site-packages\scipy\optimize\optimize.py:68, in MemoizeJac._compute_if_needed(self, x, *args)
#      66 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67     self.x = np.asarray(x).copy()
# ---> 68     fg = self.fun(x, *args)
#      69     self.jac = fg[1]
#      70     self._value = fg[0]
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\tslearn\barycenters\softdtw.py:106, in softdtw_barycenter.<locals>.f(Z)
#     105 def f(Z):
# --> 106     return _softdtw_func(Z, X_, weights, barycenter, gamma)
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\tslearn\barycenters\softdtw.py:28, in _softdtw_func(Z, X, weights, barycenter, gamma)
#      26 sdtw = SoftDTW(D, gamma=gamma)
#      27 value = sdtw.compute()
# ---> 28 E = sdtw.grad()
#      29 G_tmp = D.jacobian_product(E)
#      30 G += weights[i] * G_tmp
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\tslearn\metrics\softdtw_variants.py:785, in SoftDTW.grad(self)
#     780 D = self.be.hstack((D, self.be.zeros((m + 1, 1))))
#     782 # Allocate memory.
#     783 # We need +2 because we use indices starting from 1
#     784 # and to deal with edge cases in the recursion.
# --> 785 E = self.be.zeros((m + 2, n + 2), dtype=self.be.float64)
#     787 if self.be.is_numpy:
#     788     _njit_soft_dtw_grad(D, self.R_, E, gamma=self.gamma)
#
# KeyboardInterrupt:

# %%
N_CLUSTERS = 9

# %%
all_equip = []

for key, val in df_train_dict.items():
    val = val.copy()
    val[EQUIP_NAME] = int(key[-1])
    all_equip.append(val[CUT_VALUE:])

df_all_equips = pd.concat(all_equip, axis=0)
print(df_all_equips.shape)
# Out:
# (9334800, 18)

# %%
df_all_equips = df_all_equips.astype("float32)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[352], line 1
# ----> 1 df_all_equips.astype("float32", inplace=True)
#
# TypeError: NDFrame.astype() got an unexpected keyword argument 'inplace'

# %%
df_all_equips.drop("кластер", axis=1)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[350], line 1
# ----> 1 df_all_equips.drop("кластер", axis=1)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:4630, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4627     new_axis = axis.take(indexer)
#    4629 bm_axis = self.ndim - axis_num - 1
# -> 4630 new_mgr = self._mgr.reindex_indexer(
#    4631     new_axis,
#    4632     indexer,
#    4633     axis=bm_axis,
#    4634     allow_dups=True,
#    4635     copy=None,
#    4636     only_slice=only_slice,
#    4637 )
#    4638 result = self._constructor(new_mgr)
#    4639 if self.ndim == 1:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\internals\managers.py:740, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     737     raise IndexError("Requested axis not found in manager")
#     739 if axis == 0:
# --> 740     new_blocks = self._slice_take_blocks_ax0(
#     741         indexer,
#     742         fill_value=fill_value,
#     743         only_slice=only_slice,
#     744         use_na_proxy=use_na_proxy,
#     745     )
#     746 else:
#     747     new_blocks = [
#     748         blk.take_nd(
#     749             indexer,
#    (...)
#     755         for blk in self.blocks
#     756     ]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\internals\managers.py:898, in BaseBlockManager._slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice, use_na_proxy)
#     896                     blocks.append(nb)
#     897             else:
# --> 898                 nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#     899                 blocks.append(nb)
#     901 return blocks
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\internals\blocks.py:945, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#     942     allow_fill = True
#     944 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# --> 945 new_values = algos.take_nd(
#     946     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#     947 )
#     949 # Called from three places in managers, all of which satisfy
#     950 #  these assertions
#     951 if isinstance(self, ExtensionBlock):
#     952     # NB: in this case, the 'axis' kwarg will be ignored in the
#     953     #  algos.take_nd call above.
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\array_algos\take.py:157, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     155     out = np.empty(out_shape, dtype=dtype, order="F")
#     156 else:
# --> 157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
#     162 func(arr, indexer, out, fill_value)
#
# MemoryError: Unable to allocate 1.11 GiB for an array with shape (16, 9334800) and data type float64

# %%
# scale to have equal distance
scaler = StandardScaler()
df_test_scaled = scaler.fit_transform(df_all_equips.iloc[:,:-1])
    
# num of examples x length of timeseries x dimensions
# df_test_scaled = df_test_scaled[CUT_VALUE:]
df_test_resized = np.resize(df_test_scaled, (int(df_test_scaled.shape[0] / TIME_ANALYSE), TIME_ANALYSE, df_test_scaled.shape[1]))

print("Shape:", df_test_resized.shape)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[344], line 3
#       1 # scale to have equal distance
#       2 scaler = StandardScaler()
# ----> 3 df_test_scaled = scaler.fit_transform(df_all_equips.iloc[:,:-1])
#       5 # num of examples x length of timeseries x dimensions
#       6 # df_test_scaled = df_test_scaled[CUT_VALUE:]
#       7 df_test_resized = np.resize(df_test_scaled, (int(df_test_scaled.shape[0] / TIME_ANALYSE), TIME_ANALYSE, df_test_scaled.shape[1]))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexing.py:1598, in _iLocIndexer._getitem_tuple(self, tup)
#    1595 with suppress(IndexingError):
#    1596     return self._getitem_lowerdim(tup)
# -> 1598 return self._getitem_tuple_same_dim(tup)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexing.py:955, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     952 if com.is_null_slice(key):
#     953     continue
# --> 955 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     956 # We should never have retval.ndim < self.ndim, as that should
#     957 #  be handled by the _getitem_lowerdim call above.
#     958 assert retval.ndim == self.ndim
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexing.py:1633, in _iLocIndexer._getitem_axis(self, key, axis)
#    1627     raise IndexError(
#    1628         "DataFrame indexer is not allowed for .iloc\n"
#    1629         "Consider using .loc for automatic alignment."
#    1630     )
#    1632 if isinstance(key, slice):
# -> 1633     return self._get_slice_axis(key, axis=axis)
#    1635 if is_iterator(key):
#    1636     key = list(key)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexing.py:1669, in _iLocIndexer._get_slice_axis(self, slice_obj, axis)
#    1667 labels = obj._get_axis(axis)
#    1668 labels._validate_positional_slice(slice_obj)
# -> 1669 return self.obj._slice(slice_obj, axis=axis)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:4144, in NDFrame._slice(self, slobj, axis)
#    4142 assert isinstance(slobj, slice), type(slobj)
#    4143 axis = self._get_block_manager_axis(axis)
# -> 4144 result = self._constructor(self._mgr.get_slice(slobj, axis=axis))
#    4145 result = result.__finalize__(self)
#    4147 # this could be a view
#    4148 # but only in a single-dtyped view sliceable case
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\internals.pyx:859, in pandas._libs.internals.BlockManager.get_slice()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\internals\managers.py:898, in BaseBlockManager._slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice, use_na_proxy)
#     896                     blocks.append(nb)
#     897             else:
# --> 898                 nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#     899                 blocks.append(nb)
#     901 return blocks
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\internals\blocks.py:945, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#     942     allow_fill = True
#     944 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# --> 945 new_values = algos.take_nd(
#     946     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#     947 )
#     949 # Called from three places in managers, all of which satisfy
#     950 #  these assertions
#     951 if isinstance(self, ExtensionBlock):
#     952     # NB: in this case, the 'axis' kwarg will be ignored in the
#     953     #  algos.take_nd call above.
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\array_algos\take.py:157, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     155     out = np.empty(out_shape, dtype=dtype, order="F")
#     156 else:
# --> 157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
#     162 func(arr, indexer, out, fill_value)
#
# MemoryError: Unable to allocate 1.11 GiB for an array with shape (16, 9334800) and data type float64

# %%
# scale to have equal distance
scaler = StandardScaler()
df_test_scaled = scaler.fit_transform(df_all_equips.iloc[:,:-1])
    
# num of examples x length of timeseries x dimensions
# df_test_scaled = df_test_scaled[CUT_VALUE:]
df_test_resized = np.resize(df_test_scaled, (int(df_test_scaled.shape[0] / TIME_ANALYSE), TIME_ANALYSE, df_test_scaled.shape[1]))

print("Shape:", df_test_resized.shape)

ts_kmeans = TimeSeriesKMeans(n_clusters=N_CLUSTERS, n_init=N_INIT, metric=METRICS_CLUSTER, n_jobs=N_JOBS, max_iter=MAX_ITER, random_state=SEED)
ts_kmeans.fit(df_test_resized)
# Out:
# Shape: (77790, 120, 16)

# %% [markdown]
# 1173 min

# %%
test_eqip = 'эксгаустер 9'
idx_ = 5

scaler = StandardScaler()
df_test_scaled = scaler.fit_transform(df_train_dict[test_eqip])
    
# num of examples x length of timeseries x dimensions
df_test_scaled = df_test_scaled[CUT_VALUE:]
df_test_resized = np.resize(df_test_scaled, (int(df_test_scaled.shape[0] / TIME_ANALYSE), TIME_ANALYSE, df_test_scaled.shape[1]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1098], line 5
#       2 idx_ = 6
#       4 scaler = StandardScaler()
# ----> 5 df_test_scaled = scaler.fit_transform(df_train_dict[test_eqip])
#       7 # num of examples x length of timeseries x dimensions
#       8 df_test_scaled = df_test_scaled[CUT_VALUE:]
#
# KeyError: 'эксгаустер 10'

# %%
df_test_clusters_knn = ts_kmeans.predict(df_test_resized)
# df_knn_values = pd.Series(np.concatenate(([df_test_clusters_knn[0]] * CUT_VALUE, np.repeat(df_test_clusters_knn, TIME_ANALYSE))), name=CLUSTER_COL)
df_knn_values = pd.Series(df_test_clusters_knn, name=CLUSTER_COL, index=DT_IDXS)

# %%
for cluster_number in range(N_CLUSTERS):
    plt.plot(kmeans_examples[idx_].cluster_centers_[cluster_number, :, 0].T, label=cluster_number)
plt.title("Cluster centroids")
plt.legend()
plt.show()

# %%
ts_kshape = KShape(n_clusters=N_CLUSTERS, n_init=N_INIT, max_iter=MAX_ITER, random_state=SEED)
ts_kshape.fit(df_test_resized)
# Out:
# KShape(max_iter=10, n_clusters=9, n_init=3, random_state=42)

# %%
# df_test_clusters_shape = ts_kshape.predict(df_test_resized)
# df_train_dict[test_eqip][CLUSTER_COL+"_kshape"] = np.concatenate(([df_test_clusters_shape[0]] * CUT_VALUE, np.repeat(df_test_clusters_shape, TIME_ANALYSE)))

# for cluster_number in range(N_CLUSTERS):
#     plt.plot(ts_kshape.cluster_centers_[cluster_number, :, 0].T, label=cluster_number)
# plt.title("Cluster centroids")
# plt.legend()
# plt.show()

# %%
pca_transformed = plot_and_get_pca(np.mean(df_test_resized, axis=1), SEED, is_plot=True)
# Out:
# Explained variance of 2 components 0.6499735

# %%
tsne = TSNE(n_jobs=6, random_state=SEED)
tsne_transformed = tsne.fit_transform(pca_transformed)
plot_tsne(df_test_clusters_knn, tsne_transformed)

# tsne = TSNE(n_jobs=6, random_state=SEED)
# tsne_transformed = tsne.fit_transform(pca_transformed)
# plot_tsne(df_test_clusters_shape, tsne_transformed)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
clusters = ["кластер", "кластер_kshape"]
y_plots = [current_stator_cols, pressure_oil, bearing_temp + oil_temp, vibration_x + vibration_y, clusters]
y_axis_names = ['current_v', 'pressure_pa', 'temp_c', 'vib_µm', 'cluster_num']
y_axis_map_names = [f"y{i}" for i in range(1, len(y_plots)+1)]
y_places = [0, 0.05, 0.10, 0.95, 1.00]
plot_position = [0.10, 0.95]
savepath_plotly = PIC_EXPLORATORY_PATH / f"{visual_eqip}_knn_{visula_dates[0].replace(':', '-')}_{visula_dates[1].replace(':', '-')}.html"

df_to_visual = df_train_dict[visual_eqip].copy()
df_to_visual = df_to_visual[(df_to_visual.index >= visula_dates[0]) & (df_to_visual.index <= visula_dates[1])]
if smooth_window > 0:
    df_to_visual = df_to_visual.rolling(smooth_window).mean()

plot_time_series(df_to_visual, y_axis_map_names, y_plots, y_axis_names, y_places, plot_position, titles_plotly, savepath_plotly, colors)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'кластер'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[806], line 14
#      11 if smooth_window > 0:
#      12     df_to_visual = df_to_visual.rolling(smooth_window).mean()
# ---> 14 plot_time_series(df_to_visual, y_axis_map_names, y_plots, y_axis_names, y_places, plot_position, titles_plotly, savepath_plotly, colors)
#
# File c:\Users\parshin_sa2\Desktop\Desktop\Education\ML Advanced\proj\predictive-maintenance-rotating-equip\notebooks\..\src\visualization\plot_plotly.py:36, in plot_time_series(df_to_visual, y_axis_map_names, y_plots, y_axis_names, y_places, plot_position, titles, savepath, colors)
#      33 for y_axis_name, cols in zip(y_axis_map_names, y_plots):
#      34     for col in cols:
#      35         fig.add_trace(go.Scatter(
# ---> 36             x=df_to_visual[col].dropna().index,
#      37             y=df_to_visual[col].dropna(),
#      38             name=col,
#      39             yaxis=y_axis_name,
#      40         ))
#      42 yaxis_dict = {}
#      43 for i, (y_axis_name, y_pos) in enumerate(zip(y_axis_names, y_places)):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'кластер'

# %% [markdown]
# ## 4.2. FFT and PSD

# %%
t_n = 1                      # длина нашего сигнала в секундах
N = TIME_ANALYSE             # длина сигнала
T = t_n / N                  # период сигнала (шаг между точками?)
f_s = 1 / T                  # частота Hz
SAMPLE_RATE = 1 / f_s

DENOMINATOR = 10
PEAKS_PERCENTILE = 5
NO_PEAKS = 5

if GROUP_FREQ == '1Min':
    VALS_IN_GROUP_FREQ = int(60 / FREQ)
else:
    raise NameError

# %%
df_test_vib_scaled = df_train_vib_dict[test_eqip][CUT_VALUE * VALS_IN_GROUP_FREQ:]
df_test_vib_resized = np.resize(df_test_vib_scaled, (int(df_test_vib_scaled.shape[0] / (TIME_ANALYSE * VALS_IN_GROUP_FREQ)), TIME_ANALYSE * VALS_IN_GROUP_FREQ, df_test_vib_scaled.shape[1]))

df_test_vib_resized.shape
# Out:
# (12965, 720, 6)

# %%
_, fft_values = get_fft_values(df_test_vib_resized, T, N, f_s)
fft_values.shape
# Out:
# (12965, 60, 6)

# %%
_, psd_values = get_psd_values(df_test_vib_resized, T, N, f_s)
psd_values.shape
# Out:
# (12965, 129, 6)

# %%
fft_peaks_values = get_signals_peaks(fft_values, DENOMINATOR, PEAKS_PERCENTILE, NO_PEAKS)
psd_values_values = get_signals_peaks(psd_values, DENOMINATOR, PEAKS_PERCENTILE, NO_PEAKS)
print(fft_peaks_values.shape, psd_values_values.shape)
# Out:
# (12965, 5, 6) (12965, 5, 6)

# %%
print(fft_peaks_values.shape, psd_values_values.shape)
# Out:
# (12965, 5, 6) (12965, 5, 6)

# %%
df_fft_cols = ['fft_' + colname + f'_{i}' for i in range(1, NO_PEAKS+1) for colname in df_train_vib_dict[test_eqip].columns]
df_psd_cols = ['psd_' + colname + f'_{i}' for i in range(1, NO_PEAKS+1) for colname in df_train_vib_dict[test_eqip].columns]

df_fft_vals = pd.DataFrame(fft_peaks_values.reshape(fft_peaks_values.shape[0], -1), columns=df_fft_cols, index=DT_IDXS)
df_psd_vals = pd.DataFrame(fft_peaks_values.reshape(fft_peaks_values.shape[0], -1), columns=df_psd_cols, index=DT_IDXS)

print(df_fft_vals.shape, df_psd_vals.shape)
# Out:
# (12965, 30) (12965, 30)

# %% [markdown]
# ## 4.3. Tsfel features

# %%
from joblib import Parallel, delayed

# %%
current_stator_cols = ['ток ротора 1', 'ток ротора 2', 'ток статора']
pressure_oil = ['давление масла в системе']
bearing_temp = ['температура подшипника на опоре 1', 'температура подшипника на опоре 2', 'температура подшипника на опоре 3', 'температура подшипника на опоре 4']
oil_temp = ['температура масла в системе', 'температура масла в маслоблоке']

# %%
TSFEL_CFG_FILE = tsfel.get_features_by_domain() # tsfel.get_features_by_domain('temporal')
SAMPLING_FREQ = TIME_ANALYSE
TSFEL_TRESH = 0.85

# %%
def get_tsfel_features(df_test_resized: pd.DataFrame):
    tsfel_feature = np.empty((df_test_resized.shape[0], 194))
    for sample_idx in range(tsfel_feature.shape[0]):
        tsfel_feature[sample_idx, :] = tsfel.time_series_features_extractor(TSFEL_CFG_FILE, df_test_resized[sample_idx, :], fs=SAMPLING_FREQ, verbose=False)
        
def get_lists_joblib(df_test_resized: pd.DataFrame, n_jobs=16):
    Parallel(n_jobs=n_jobs)(delayed(get_tsfel_features)(df_test_resized[[colname]]) for colname in df_test_resized.columns)

# %%
res = get_lists_joblib(df_test_resized[:1000,:,:], n_jobs=16)

# %%
tsfel_equips = []

tsfel_features = np.empty((df_test_resized.shape[0], 194, df_test_resized.shape[2]))

for feature_idx in tqdm(range(tsfel_features.shape[2]), leave=False):
    for sample_idx in tqdm(range(tsfel_features.shape[0]), leave=False):
        tsfel_features[sample_idx, :, feature_idx] = tsfel.time_series_features_extractor(TSFEL_CFG_FILE, df_test_resized[sample_idx, :, feature_idx], fs=SAMPLING_FREQ, verbose=False)

print(tsfel_features.shape)
tsfel_equips.append(tsfel_features)

# %%
def select_var_threshold(df: pd.DataFrame, threshold: float = 0.5) -> pd.DataFrame:
    selector = VarianceThreshold(threshold)
    selector.fit(df)
    return df[df.columns[selector.get_support(indices=True)]]

# %%
equip_names = []

for equip_name in EQUIP_NAMES:

    tsfel_list = []
    tsfel_columns = tsfel.time_series_features_extractor(TSFEL_CFG_FILE, df_train_dict[equip_name].iloc[:SAMPLING_FREQ,0], fs=SAMPLING_FREQ, verbose=False).columns


    for idx in range(tsfel_features.shape[2]):
        # Highly correlated features are removed
        colname = df_train_dict[equip_name].columns[idx] 
        columns_ = colname + tsfel_columns.str[1:]
        features_ = pd.DataFrame(tsfel_features[:,:,idx], columns=columns_, index=DT_IDXS)
        corr_features = tsfel.correlated_features(features_, threshold=TSFEL_TRESH)
        features_.drop(corr_features, axis=1, inplace=True)

        # Remove low variance features
        features_ = select_var_threshold(features_)

        print(f"Num of samples x features in {colname}:", features_.shape)
        
        tsfel_list.append(features_)
        
    df_tsfel = pd.concat(tsfel_list, axis=1)
    print(df_tsfel.shape)
    equip_names.append(df_tsfel)
# Out:
# Num of samples x features in ток ротора 1: (12965, 32)
# Num of samples x features in ток ротора 2: (12965, 32)
# Num of samples x features in ток статора: (12965, 36)
# Num of samples x features in давление масла в системе: (12965, 33)
# Num of samples x features in температура подшипника на опоре 1: (12965, 34)
# Num of samples x features in температура подшипника на опоре 2: (12965, 33)
# Num of samples x features in температура подшипника на опоре 3: (12965, 34)
# Num of samples x features in температура подшипника на опоре 4: (12965, 34)
# Num of samples x features in температура масла в системе: (12965, 36)
# Num of samples x features in температура масла в маслоблоке: (12965, 34)
# Num of samples x features in вибрация на опоре 1: (12965, 35)
# Num of samples x features in вибрация на опоре 2: (12965, 34)
# Num of samples x features in вибрация на опоре 3: (12965, 35)
# Num of samples x features in вибрация на опоре 4: (12965, 34)
# Num of samples x features in вибрация на опоре 3. продольная.: (12965, 31)
# Num of samples x features in вибрация на опоре 4. продольная.: (12965, 33)
# (12965, 540)
# Num of samples x features in ток ротора 1: (12965, 32)
# Num of samples x features in ток ротора 2: (12965, 32)
# Num of samples x features in ток статора: (12965, 36)
# Num of samples x features in давление масла в системе: (12965, 33)
# Num of samples x features in температура подшипника на опоре 1: (12965, 34)
# Num of samples x features in температура подшипника на опоре 2: (12965, 33)
# Num of samples x features in температура подшипника на опоре 3: (12965, 34)
# Num of samples x features in температура подшипника на опоре 4: (12965, 34)
# Num of samples x features in температура масла в системе: (12965, 36)
# Num of samples x features in температура масла в маслоблоке: (12965, 34)
# Num of samples x features in вибрация на опоре 1: (12965, 35)
# Num of samples x features in вибрация на опоре 2: (12965, 34)
# Num of samples x features in вибрация на опоре 3: (12965, 35)
# Num of samples x features in вибрация на опоре 4: (12965, 34)
# Num of samples x features in вибрация на опоре 3. продольная.: (12965, 31)
# Num of samples x features in вибрация на опоре 4. продольная.: (12965, 33)
# (12965, 540)
# Num of samples x features in ток ротора 1: (12965, 32)
# Num of samples x features in ток ротора 2: (12965, 32)
# Num of samples x features in ток статора: (12965, 36)
# Num of samples x features in давление масла в системе: (12965, 33)
# Num of samples x features in температура подшипника на опоре 1: (12965, 34)
# Num of samples x features in температура подшипника на опоре 2: (12965, 33)
# Num of samples x features in температура подшипника на опоре 3: (12965, 34)
# Num of samples x features in температура подшипника на опоре 4: (12965, 34)
# Num of samples x features in температура масла в системе: (12965, 36)
# Num of samples x features in температура масла в маслоблоке: (12965, 34)
# Num of samples x features in вибрация на опоре 1: (12965, 35)
# Num of samples x features in вибрация на опоре 2: (12965, 34)
# Num of samples x features in вибрация на опоре 3: (12965, 35)
# Num of samples x features in вибрация на опоре 4: (12965, 34)
# Num of samples x features in вибрация на опоре 3. продольная.: (12965, 31)
# Num of samples x features in вибрация на опоре 4. продольная.: (12965, 33)
# (12965, 540)
# Num of samples x features in ток ротора 1: (12965, 32)
# Num of samples x features in ток ротора 2: (12965, 32)
# Num of samples x features in ток статора: (12965, 36)
# Num of samples x features in давление масла в системе: (12965, 33)
# Num of samples x features in температура подшипника на опоре 1: (12965, 34)
# Num of samples x features in температура подшипника на опоре 2: (12965, 33)
# Num of samples x features in температура подшипника на опоре 3: (12965, 34)
# Num of samples x features in температура подшипника на опоре 4: (12965, 34)
# Num of samples x features in температура масла в системе: (12965, 36)
# Num of samples x features in температура масла в маслоблоке: (12965, 34)
# Num of samples x features in вибрация на опоре 1: (12965, 35)
# Num of samples x features in вибрация на опоре 2: (12965, 34)
# Num of samples x features in вибрация на опоре 3: (12965, 35)
# Num of samples x features in вибрация на опоре 4: (12965, 34)
# Num of samples x features in вибрация на опоре 3. продольная.: (12965, 31)
# Num of samples x features in вибрация на опоре 4. продольная.: (12965, 33)
# (12965, 540)
# Num of samples x features in ток ротора 1: (12965, 32)
# Num of samples x features in ток ротора 2: (12965, 32)
# Num of samples x features in ток статора: (12965, 36)
# Num of samples x features in давление масла в системе: (12965, 33)
# Num of samples x features in температура подшипника на опоре 1: (12965, 34)
# Num of samples x features in температура подшипника на опоре 2: (12965, 33)
# Num of samples x features in температура подшипника на опоре 3: (12965, 34)
# Num of samples x features in температура подшипника на опоре 4: (12965, 34)
# Num of samples x features in температура масла в системе: (12965, 36)
# Num of samples x features in температура масла в маслоблоке: (12965, 34)
# Num of samples x features in вибрация на опоре 1: (12965, 35)
# Num of samples x features in вибрация на опоре 2: (12965, 34)
# Num of samples x features in вибрация на опоре 3: (12965, 35)
# Num of samples x features in вибрация на опоре 4: (12965, 34)
# Num of samples x features in вибрация на опоре 3. продольная.: (12965, 31)
# Num of samples x features in вибрация на опоре 4. продольная.: (12965, 33)
# (12965, 540)
# Num of samples x features in ток ротора 1: (12965, 32)
# Num of samples x features in ток ротора 2: (12965, 32)
# Num of samples x features in ток статора: (12965, 36)
# Num of samples x features in давление масла в системе: (12965, 33)
# Num of samples x features in температура подшипника на опоре 1: (12965, 34)
# Num of samples x features in температура подшипника на опоре 2: (12965, 33)
# Num of samples x features in температура подшипника на опоре 3: (12965, 34)
# Num of samples x features in температура подшипника на опоре 4: (12965, 34)
# Num of samples x features in температура масла в системе: (12965, 36)
# Num of samples x features in температура масла в маслоблоке: (12965, 34)
# Num of samples x features in вибрация на опоре 1: (12965, 35)
# Num of samples x features in вибрация на опоре 2: (12965, 34)
# Num of samples x features in вибрация на опоре 3: (12965, 35)
# Num of samples x features in вибрация на опоре 4: (12965, 34)
# Num of samples x features in вибрация на опоре 3. продольная.: (12965, 31)
# Num of samples x features in вибрация на опоре 4. продольная.: (12965, 33)
# (12965, 540)

# %% [markdown]
# ## 4.4. Time-based features

# %%
df_month = pd.Series(DT_IDXS.month, name="month", index=DT_IDXS) 
df_day = pd.Series(((DT_IDXS.hour > 6) & (DT_IDXS.hour <= 18)), name="is_day", index=DT_IDXS)
df_time_values = pd.concat([df_month, df_day], axis=1)

df_time_values.shape
# Out:
# (12965, 2)

# %% [markdown]
# ## 4.5. State-based features

# %%
df_train_state = df_train_state_dict[test_eqip][CUT_VALUE:]
df_train_state = df_train_state.groupby(pd.Grouper(freq=str(TIME_ANALYSE) + "min")).aggregate(GROUP_FUNC_Y)
df_train_state = df_train_state.astype(np.int8)
df_train_state.columns += "_state"
print(df_train_state.shape)
# Out:
# (12965, 16)

# %% [markdown]
# ## 4.6. Gather all features

# %%
# kNN
print("kNN feature", df_knn_values.shape)

# ftt, psd
print("FFT and PSD features", df_fft_vals.shape, df_psd_vals.shape)

# tsfel
# print("TSFEL features", df_tsfel.shape)

# time features
print("Time-based features", df_time_values.shape)

# state features
print("State features", df_train_state.shape)

# all features
df_preproc_features = pd.concat([df_knn_values,
                                 df_fft_vals,
                                #  df_tsfel,
                                 df_time_values,
                                 df_train_state], axis=1)
print(df_preproc_features.shape)
# Out:
# kNN feature (12965,)
# FFT and PSD features (12965, 30) (12965, 30)
# Time-based features (12965, 2)
# State features (12965, 16)
# (12965, 49)

# %%
df_preproc_features.to_csv(DATA_PROC_PATH / (test_eqip.replace(' ', '_') + '_' + datetime.today().strftime('%Y-%m-%d') + SAVE_EXT))
# df_meta.to_csv(DATA_PROC_PATH / (METAINFO_SAVE + SAVE_EXT))

# %%
# df_preproc_features = pd.read_csv(DATA_PROC_PATH / "эксгаустер_5_2023-10-16.csv", index_col=DATETIME_COL)

# df_meta = pd.read_csv(DATA_PROC_PATH / (METAINFO_SAVE + SAVE_EXT))
# df_meta.drop("Unnamed: 0", axis=1, inplace=True)

# test_eqip = "эксгаустер 5"

# %%
# df_meta[(df_meta[EQUIP_NAME] == test_eqip) & (df_meta[FAILURE_TYPE_COL] == FAILURES_CODES["malfunction"])]
df_target_m3 = pd.DataFrame(0, columns=df_meta[FAILURE_PART_COL].unique(), index=DT_IDXS)

for idx, df_row in df_meta[(df_meta[EQUIP_NAME] == test_eqip) & (df_meta[FAILURE_TYPE_COL] == FAILURES_CODES["malfunction"])].iterrows():
    failure_part_col_ = df_row[FAILURE_PART_COL]
    date_filter_ = (df_target_m3.index >= df_row[START_END_FAILURE_DATES[0]]) & (df_target_m3.index <= df_row[START_END_FAILURE_DATES[1]])
    df_target_m3.loc[date_filter_, failure_part_col_] += 1
    
df_target_m3.where(df_target_m3 <= 1, 1, inplace=True)

# %% [markdown]
# ## 5. Prepare target

# %%
# 'сапфир 22 мдд разрежение в коллекторе' - датчик измерения давления разрежения
#  'тр-р тм-6300-10/6', 'тр-р тм-4000-10/6' - трансформатор
# 'метран-100 датчики давления'
FAILURE_TRANSFORMER = {'эксгаустер 4': 'тр-р тм-4000-10/6',
                       'эксгаустер 5': 'тр-р тм-4000-10/6',
                       'эксгаустер 6': 'тр-р тм-4000-10/6',
                       'эксгаустер 7': 'тр-р тм-4000-10/6',
                       'эксгаустер 8': 'тр-р тм-6300-10/6',
                       'эксгаустер 9': 'тр-р тм-6300-10/6',
                       }

FAILURE_GROUPS = {'oil_equip': ['маслостанция жидкой смазки', 'маслоохладитель  м-05-1', 'маслонасос рабочий', 'тсмт-101-010-50м-80 термопреобр.масло', 'гсм', 'маслопроводы', 'маслобак', 'масляный фильтр', 'двигатель пускового маслонасоса',
                                'маслонасос шестеренчатый (рез.)', 'маслонасос шестеренчатый (пуск.)',],
                  'electric_equip_common': ['электродвигатель дспу-140-84-4', 'электроаппаратура',
                                            'кл1 тр до эд', 'кл2 тр до эд',
                                            'электрооборудования',
                                            'тиристорный возбудитель спвд-м10-400-5', 'тирист. возбудитель вт-рэм-400 ву1', 'тиристорный возбудитель тв-400 ву1', 'тирист. возбудитель вт-рэм-400 ву2'], 
                  'rotating': ['ротор'],
                  'valves': ['запорная арматура', 'редуктор газ. задвижки', 'задвижка', 'эл/двигатель газ. задвижки', 'зап. и рег. арматура', 'газовая задвижка а/м'],
                  'bearings_mech': ['подшипник опорный',
                                    'подшипник опорный №1', 'подшипник опорный №2',
                                    'вк 310с вибропреобразователь т.1', 'вк 310с вибропреобразователь т.2', 'вк 310с вибропреобразователь т.3', 'вк 310с вибропреобразователь т.4',
                                    'подшипник опорно-упорный', ],
                  'bearing_temp': ['тсмт-101-010-50м-400 термопр.подш.т.1', 'тсмт-101-010-50м-400 термопр.подш.т.2', 'тсмт-101-010-50м-200 термопр.подш.т.3', 'тсмт-101-010-50м-200 термопр.подш.т.4'],
                  'static_equp': ['корпус', 'улита', 'кожух муфты', ],
                  'process': ['сапфир 22 мдд разрежение в коллекторе', 'сапфир 22 мдд перепад давл. на циклоне', 'метран-100 датчики давления', 'эксгаустер а/м', ]}

failure_name_group = {}

for key, vals in FAILURE_GROUPS.items():
    for val in vals:
        failure_name_group[val] = key

# %%
df_target_renamed_m3 = df_target_m3.rename(failure_name_group, axis=1)
df_target_unique_cols = list(FAILURE_GROUPS.keys()) + [FAILURE_TRANSFORMER[test_eqip]]
target_grouped_m3 = {}


for col in df_target_unique_cols:
    if df_target_renamed_m3[[col]].shape[1] > 1:
        target_grouped_m3[col] = df_target_renamed_m3[col].sum(axis=1)
    else: 
        target_grouped_m3[col] = df_target_renamed_m3[col]
        
df_target_grouped_m3 = pd.DataFrame(target_grouped_m3)
df_target_grouped_m3.where(df_target_grouped_m3 <= 1, 1, inplace=True)

# %%
display(df_target_grouped_m3.describe())
print(df_target_grouped_m3.sum())
# Out:
#           oil_equip  electric_equip_common      rotating        valves  \
# count  12965.000000           12965.000000  12965.000000  12965.000000
# mean       0.885769               0.803085      0.064173      0.698573
# std        0.318103               0.397683      0.245070      0.458895
# min        0.000000               0.000000      0.000000      0.000000
# 25%        1.000000               1.000000      0.000000      0.000000
# 50%        1.000000               1.000000      0.000000      1.000000
# 75%        1.000000               1.000000      0.000000      1.000000
# max        1.000000               1.000000      1.000000      1.000000
#
#        bearings_mech  bearing_temp   static_equp       process  \
# count   12965.000000       12965.0  12965.000000  12965.000000
# mean        0.659005           0.0      0.488469      0.000154
# std         0.474062           0.0      0.499886      0.012420
# min         0.000000           0.0      0.000000      0.000000
# 25%         0.000000           0.0      0.000000      0.000000
# 50%         1.000000           0.0      0.000000      0.000000
# 75%         1.000000           0.0      1.000000      0.000000
# max         1.000000           0.0      1.000000      1.000000
#
#        тр-р тм-4000-10/6
# count       12965.000000
# mean            0.051986
# std             0.222008
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max             1.000000
# oil_equip                11484
# electric_equip_common    10412
# rotating                   832
# valves                    9057
# bearings_mech             8544
# bearing_temp                 0
# static_equp               6333
# process                      2
# тр-р тм-4000-10/6          674
# dtype: int64

# %%
# df_train_init = df_train_dict[test_eqip][CUT_VALUE:]
df_train_init = pd.read_csv(DATA_INTER_PATH / "эксгаустер 5_train.csv", index_col='dt')
df_train_init.index = pd.to_datetime(df_train_init.index)
df_train_init = df_train_init.groupby(pd.Grouper(freq=str(TIME_ANALYSE) + "min")).aggregate(GROUP_FUNC_Y)
df_train_init = df_train_init[1:]

# %% [markdown]
# # 6. Baseline

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import VarianceThreshold, SelectFromModel
from sklearn.ensemble import RandomForestClassifier, ExtraTreesRegressor
from sklearn.model_selection import RandomizedSearchCV, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, multilabel_confusion_matrix
from sklearn.inspection import permutation_importance

from skmultilearn.model_selection import iterative_train_test_split
from skmultilearn.model_selection.measures import get_combination_wise_output_matrix

from collections import Counter

# %%
X_train, y_train, X_test, y_test = iterative_train_test_split(sparse.csr_matrix(df_train_init.values), sparse.csr_matrix(df_target_grouped_m3.values), test_size = 0.3,)

class_balance = pd.DataFrame({
    'train': Counter(str(combination) for row in get_combination_wise_output_matrix(y_train.A, order=2) for combination in row),
    'test' : Counter(str(combination) for row in get_combination_wise_output_matrix(y_test.A, order=2) for combination in row)
}).T.fillna(0.0)
print("Balance vals:\n", class_balance.loc["test", :] / (class_balance.loc["test", :] + class_balance.loc["train", :]))
# Out:
# Balance vals:
#  (0, 0)    0.316353
# (0, 1)    0.299990
# (1, 1)    0.311275
# (0, 6)    0.300037
# (6, 6)    0.300016
# (1, 6)    0.299979
# (4, 4)    0.395599
# (0, 4)    0.391363
# (3, 4)    0.418049
# (0, 3)    0.299975
# (4, 6)    0.343794
# (1, 4)    0.381497
# (3, 3)    0.304957
# (3, 6)    0.299977
# (1, 3)    0.282777
# (0, 8)    0.000000
# (6, 8)    0.015544
# (4, 8)    0.004706
# (8, 8)    0.044510
# (1, 8)    0.044510
# (3, 8)    0.044510
# (2, 4)    0.002833
# (1, 2)    0.103365
# (0, 2)    0.000000
# (2, 6)    0.011583
# (2, 2)    0.103365
# (2, 3)    0.109694
# (0, 7)    0.000000
# (7, 7)    0.000000
# (3, 7)    0.000000
# (1, 7)    0.000000
# (2, 8)    0.064302
# dtype: float64

# %%
n_iter = 50 # 100
# Scorer

numeric_transformer = Pipeline(
    steps=[("imputer", SimpleImputer(strategy="mean")), 
           ("scaler", StandardScaler())
    ]
)


feature_selector = VarianceThreshold(.99 * (1 - .99)) # SelectFromModel(ExtraTreesRegressor(min_samples_leaf=10, random_state=SEED))
# feature_selector = PermutationImportance(LogisticRegression(penalty="l1", solver='liblinear'), scoring=cr_scorer, cv=None)

clf = Pipeline(
    steps=[("preprocessor", numeric_transformer),
           ("feature_selector", feature_selector),
           ("classifier", RandomForestClassifier(n_estimators=500, min_samples_leaf=10, max_depth=20, class_weight='balanced', random_state=SEED))]
)

param_grid = {
    'classifier__n_estimators': [20, 50, 100, 500], # np.linspace(-10, 10)
    'classifier__max_depth': [10, 20, 30, 50],
    'classifier__min_samples_leaf': [10, 15, 20],
    'classifier__class_weight': ['balanced', None],
    'preprocessor__imputer__strategy':['median', 'mean']
}

cv_cls = 5 # StratifiedKFold(n_splits=5, shuffle=False)

search = RandomizedSearchCV(clf,
                            param_grid, 
                            n_iter=n_iter,
                            verbose=True, 
                            n_jobs=-1,
                            cv=cv_cls, 
                            random_state=SEED)

clf
# Out:
# Pipeline(steps=[('preprocessor',
#                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                  ('scaler', StandardScaler())])),
#                 ('feature_selector',
#                  VarianceThreshold(threshold=0.00990000000000001)),
#                 ('classifier',
#                  RandomForestClassifier(class_weight='balanced', max_depth=20,
#                                         min_samples_leaf=10, n_estimators=500,
#                                         random_state=42))])

# %%
clf.fit(X_train, y_train)
# print("Best params:", search.best_params_)
# print("Best score:", search.best_score_)
predictions_1 = clf.predict(X_train)
predictions_1_test = clf.predict(X_test)
# Out:
# c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\base.py:458: UserWarning: X has feature names, but SimpleImputer was fitted without feature names
#   warnings.warn(

# %%
matrixes_res = multilabel_confusion_matrix(y_train, predictions_1)

for matrix in matrixes_res:
    FP = matrix[0][1]
    FN = matrix[1][0]
    TP = matrix[1][1]
    TN = matrix[0][0]
    
    print(f"{TP / (TP + FN + FP):2f}")
# Out:
# 0.995288
# 0.980368
# 0.749748
# 0.986412
# 0.950969
# nan
# 0.959713
# 1.000000
# 0.702198
# C:\Users\parshin_sa2\AppData\Local\Temp\ipykernel_38688\3832224685.py:9: RuntimeWarning: invalid value encountered in longlong_scalars
#   print(f"{TP / (TP + FN + FP):2f}")

# %%
matrixes_res = multilabel_confusion_matrix(y_test, predictions_1_test)

for matrix in matrixes_res:
    FP = matrix[0][1]
    FN = matrix[1][0]
    TP = matrix[1][1]
    TN = matrix[0][0]
    
    print(f"{TP / (TP + FN + FP):2f}")
# Out:
# 0.954784
# 0.927956
# 0.064286
# 0.965812
# 0.952855
# nan
# 0.875291
# nan
# 0.071429
# C:\Users\parshin_sa2\AppData\Local\Temp\ipykernel_38688\3177970742.py:9: RuntimeWarning: invalid value encountered in longlong_scalars
#   print(f"{TP / (TP + FN + FP):2f}")

# %%
print(classification_report(y_test, predictions_1_test, target_names=df_target_grouped_m3.columns))
# Out:
#                        precision    recall  f1-score   support
#
#             oil_equip       0.96      1.00      0.98      3633
# electric_equip_common       1.00      0.93      0.96      3241
#              rotating       0.14      0.10      0.12        86
#                valves       0.98      0.98      0.98      2762
#         bearings_mech       0.99      0.96      0.98      3380
#          bearing_temp       0.00      0.00      0.00         0
#           static_equp       0.88      0.99      0.93      1900
#               process       0.00      0.00      0.00         0
#     тр-р тм-4000-10/6       0.10      0.20      0.13        30
#
#             micro avg       0.96      0.97      0.96     15032
#             macro avg       0.56      0.57      0.57     15032
#          weighted avg       0.96      0.97      0.96     15032
#           samples avg       0.96      0.96      0.95     15032
# c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
multilabel_confusion_matrix(y_test, predictions_1_test)
# Out:
# array([[[ 315,  171],
#         [   1, 3632]],
#
#        [[ 871,    7],
#         [ 227, 3014]],
#
#        [[3979,   54],
#         [  77,    9]],
#
#        [[1311,   46],
#         [  50, 2712]],
#
#        [[ 704,   35],
#         [ 126, 3254]],
#
#        [[4119,    0],
#         [   0,    0]],
#
#        [[1970,  249],
#         [  19, 1881]],
#
#        [[4119,    0],
#         [   0,    0]],
#
#        [[4035,   54],
#         [  24,    6]]], dtype=int64)

# %% [markdown]
# # 7. Other versions

# %%
X_train, y_train, X_test, y_test

# %%
from skmultilearn.adapt import MLTSVM
from scipy import sparse

# %%
parameters = {'c_k': [2**i for i in range(-5, 5, 2)]}
score = 'f1_micro'

clf = GridSearchCV(MLTSVM(), parameters, scoring=score)
clf.fit(X_train, y_train)

print(clf.best_params_, clf.best_score_)
# Out:
# c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\model_selection\_validation.py:821: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\model_selection\_validation.py", line 810, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\metrics\_scorer.py", line 266, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#   File "c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\metrics\_scorer.py", line 353, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\metrics\_scorer.py", line 86, in _cached_call
#     result, _ = _get_response_values(
#   File "c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\utils\_response.py", line 182, in _get_response_values
#     classes = estimator.classes_
# AttributeError: 'MLTSVM' object has no attribute 'classes_'
#
#   warnings.warn(
# c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan]
#   warnings.warn(
# {'c_k': 0.03125} nan

# %%
classifier = MLTSVM(c_k = 0.03125)
classifier.fit(X_train, y_train)
predictions = classifier.predict(X_test)

# %%
predictions = clf.predict(X_test)

# %%
print(classification_report(y_test, predictions, target_names=df_target_grouped_m3.columns))
# Out:
#                        precision    recall  f1-score   support
#
#             oil_equip       0.99      0.37      0.54      3633
# electric_equip_common       0.99      0.36      0.53      3241
#              rotating       0.09      0.13      0.10        86
#                valves       0.73      0.39      0.51      2762
#         bearings_mech       0.98      0.17      0.29      3380
#          bearing_temp       0.00      0.00      0.00         0
#           static_equp       0.50      0.16      0.24      1900
#               process       0.00      0.00      0.00         0
#     тр-р тм-4000-10/6       0.00      0.00      0.00        30
#
#             micro avg       0.77      0.30      0.43     15032
#             macro avg       0.48      0.17      0.25     15032
#          weighted avg       0.87      0.30      0.43     15032
#           samples avg       0.34      0.25      0.27     15032
# c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
feature_selector_2 = SelectFromModel(ExtraTreesRegressor(min_samples_leaf=10, random_state=SEED))

clf_3 = Pipeline(
    steps=[("preprocessor", numeric_transformer),
           ("feature_selector", feature_selector_2),
           ("classifier", RandomForestClassifier(n_estimators=500, min_samples_leaf=10, max_depth=20, class_weight='balanced', random_state=SEED))]
)

search_2 = RandomizedSearchCV(clf_3,
                              param_grid, 
                              n_iter=n_iter,
                              verbose=True, 
                              n_jobs=-1,
                              cv=cv_cls, 
                              random_state=SEED)

# %%
X_train, y_train, X_test, y_test = iterative_train_test_split(df_preproc_features.values, df_target_grouped_m3.values, test_size = 0.3,)

class_balance = pd.DataFrame({
    'train': Counter(str(combination) for row in get_combination_wise_output_matrix(y_train, order=2) for combination in row),
    'test' : Counter(str(combination) for row in get_combination_wise_output_matrix(y_test, order=2) for combination in row)
}).T.fillna(0.0)
print("Balance vals:\n", class_balance.loc["test", :] / (class_balance.loc["test", :] + class_balance.loc["train", :]))
# Out:
# Balance vals:
#  (0, 0)    0.316353
# (0, 1)    0.299990
# (1, 1)    0.311275
# (0, 6)    0.300037
# (6, 6)    0.300016
# (1, 6)    0.299979
# (4, 4)    0.395599
# (0, 4)    0.391363
# (3, 4)    0.418049
# (0, 3)    0.299975
# (4, 6)    0.343794
# (1, 4)    0.381497
# (3, 3)    0.304957
# (3, 6)    0.299977
# (1, 3)    0.282777
# (0, 8)    0.000000
# (6, 8)    0.015544
# (4, 8)    0.004706
# (8, 8)    0.044510
# (1, 8)    0.044510
# (3, 8)    0.044510
# (2, 4)    0.002833
# (1, 2)    0.103365
# (0, 2)    0.000000
# (2, 6)    0.011583
# (2, 2)    0.103365
# (2, 3)    0.109694
# (0, 7)    0.000000
# (7, 7)    0.000000
# (3, 7)    0.000000
# (1, 7)    0.000000
# (2, 8)    0.064302
# dtype: float64

# %%
clf_3.fit(X_train, y_train)
predictions_2 = clf_3.predict(X_train)
predictions_2_test = clf_3.predict(X_test)

# %%
selected_features = df_preproc_features.columns[clf_3['feature_selector'].get_support()]
print(f"Chosen params: {clf_3['feature_selector'].get_support().sum()} / {len(clf_3['feature_selector'].get_support())}")
# Out:
# Chosen params: 81 / 589

# %%
selected_features_dict = {feature_name: [] for feature_name in FEATURE_NAMES}
selected_features_dict["others"] = []
for selected_feature in selected_features:
    not_exists = True
    for feature_name in FEATURE_NAMES[::-1]:
        if feature_name in selected_feature:
            not_exists = False
            selected_features_dict[feature_name].append(selected_feature)
            break
    if not_exists:
        selected_features_dict["others"].append(selected_feature)
df_selected_features = pd.DataFrame.from_dict(selected_features_dict, orient="index").T
print("Num of features:", df_selected_features.notna().sum().sum())
display(df_selected_features)
# Out:
# Num of features: 81
#                       ток ротора 1                    ток ротора 2  \
# 0     ток ротора 1_Absolute energy    ток ротора 2_Absolute energy
# 1   ток ротора 1_ECDF Percentile_0  ток ротора 2_ECDF Percentile_0
# 2         ток ротора 1_Histogram_5        ток ротора 2_Histogram_5
# 3         ток ротора 1_Histogram_6        ток ротора 2_Histogram_6
# 4         ток ротора 1_Histogram_7        ток ротора 2_Histogram_7
# 5         ток ротора 1_Histogram_8        ток ротора 2_Histogram_8
# 6                 ток ротора 1_Min        ток ротора 2_Histogram_9
# 7                             None                ток ротора 2_Min
# 8                             None                            None
# 9                             None                            None
# 10                            None                            None
#
#                       ток статора                    давление масла в системе  \
# 0   ток статора_ECDF Percentile_1    давление масла в системе_Absolute energy
# 1         ток статора_Histogram_5  давление масла в системе_ECDF Percentile_0
# 2                            None        давление масла в системе_Histogram_1
# 3                            None        давление масла в системе_Histogram_3
# 4                            None        давление масла в системе_Histogram_4
# 5                            None        давление масла в системе_Histogram_5
# 6                            None        давление масла в системе_Histogram_6
# 7                            None        давление масла в системе_Histogram_7
# 8                            None        давление масла в системе_Histogram_8
# 9                            None        давление масла в системе_Histogram_9
# 10                           None  давление масла в системе_Maximum frequency
#
#                     температура подшипника на опоре 1  \
# 0   температура подшипника на опоре 1_Absolute energy
# 1   температура подшипника на опоре 1_ECDF Percent...
# 2       температура подшипника на опоре 1_Histogram_8
# 3            температура подшипника на опоре 1_MFCC_1
# 4              температура подшипника на опоре 1_Mean
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
#
#                     температура подшипника на опоре 2  \
# 0   температура подшипника на опоре 2_Negative tur...
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
#
#                     температура подшипника на опоре 3  \
# 0   температура подшипника на опоре 3_ECDF Percent...
# 1            температура подшипника на опоре 3_MFCC_1
# 2   температура подшипника на опоре 3_Negative tur...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
#
#            температура подшипника на опоре 4  \
# 0   температура подшипника на опоре 4_MFCC_1
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# 5                                       None
# 6                                       None
# 7                                       None
# 8                                       None
# 9                                       None
# 10                                      None
#
#                       температура масла в системе  \
# 0     температура масла в системе_Absolute energy
# 1   температура масла в системе_ECDF Percentile_0
# 2   температура масла в системе_ECDF Percentile_1
# 3   температура масла в системе_Maximum frequency
# 4                 температура масла в системе_Min
# 5     температура масла в системе_Power bandwidth
# 6                                            None
# 7                                            None
# 8                                            None
# 9                                            None
# 10                                           None
#
#            температура масла в маслоблоке  \
# 0   температура масла в маслоблоке_MFCC_1
# 1   температура масла в маслоблоке_Median
# 2                                    None
# 3                                    None
# 4                                    None
# 5                                    None
# 6                                    None
# 7                                    None
# 8                                    None
# 9                                    None
# 10                                   None
#
#                       вибрация на опоре 1  \
# 0     вибрация на опоре 1_Absolute energy
# 1   вибрация на опоре 1_ECDF Percentile_0
# 2   вибрация на опоре 1_Maximum frequency
# 3                                    None
# 4                                    None
# 5                                    None
# 6                                    None
# 7                                    None
# 8                                    None
# 9                                    None
# 10                                   None
#
#                       вибрация на опоре 2  \
# 0               fft_вибрация на опоре 2_4
# 1               fft_вибрация на опоре 2_5
# 2     вибрация на опоре 2_Absolute energy
# 3   вибрация на опоре 2_ECDF Percentile_0
# 4                                    None
# 5                                    None
# 6                                    None
# 7                                    None
# 8                                    None
# 9                                    None
# 10                                   None
#
#                       вибрация на опоре 3  \
# 0               fft_вибрация на опоре 3_3
# 1               fft_вибрация на опоре 3_4
# 2               fft_вибрация на опоре 3_5
# 3     вибрация на опоре 3_Absolute energy
# 4   вибрация на опоре 3_ECDF Percentile_0
# 5         вибрация на опоре 3_Histogram_1
# 6         вибрация на опоре 3_Histogram_2
# 7         вибрация на опоре 3_Histogram_3
# 8   вибрация на опоре 3_Maximum frequency
# 9                                    None
# 10                                   None
#
#                       вибрация на опоре 4  \
# 0               fft_вибрация на опоре 4_3
# 1               fft_вибрация на опоре 4_4
# 2               fft_вибрация на опоре 4_5
# 3     вибрация на опоре 4_Absolute energy
# 4   вибрация на опоре 4_ECDF Percentile_0
# 5         вибрация на опоре 4_Histogram_2
# 6         вибрация на опоре 4_Histogram_3
# 7         вибрация на опоре 4_Histogram_4
# 8                                    None
# 9                                    None
# 10                                   None
#
#                     вибрация на опоре 3. продольная.  \
# 0             fft_вибрация на опоре 3. продольная._5
# 1   вибрация на опоре 3. продольная._Absolute energy
# 2       вибрация на опоре 3. продольная._Histogram_3
# 3       вибрация на опоре 3. продольная._Histogram_4
# 4                                               None
# 5                                               None
# 6                                               None
# 7                                               None
# 8                                               None
# 9                                               None
# 10                                              None
#
#                      вибрация на опоре 4. продольная.       others
# 0              fft_вибрация на опоре 4. продольная._3  кластер_knn
# 1   вибрация на опоре 4. продольная._ECDF Percenti...        month
# 2        вибрация на опоре 4. продольная._Histogram_0         None
# 3        вибрация на опоре 4. продольная._Histogram_1         None
# 4        вибрация на опоре 4. продольная._Histogram_2         None
# 5                                                None         None
# 6                                                None         None
# 7                                                None         None
# 8                                                None         None
# 9                                                None         None
# 10                                               None         None

# %%
matrixes_res = multilabel_confusion_matrix(y_test, predictions_2_test)

for matrix in matrixes_res:
    FP = matrix[0][1]
    FN = matrix[1][0]
    TP = matrix[1][1]
    TN = matrix[0][0]
    
    print(f"{TP / (TP + FN + FP):2f}")
# Out:
# 0.954044
# 0.949585
# 0.897727
# 0.978402
# 0.914537
# nan
# 0.837483
# nan
# 0.391892
# C:\Users\parshin_sa2\AppData\Local\Temp\ipykernel_38688\2853854036.py:9: RuntimeWarning: invalid value encountered in longlong_scalars
#   print(f"{TP / (TP + FN + FP):2f}")

# %%
print(classification_report(y_test, predictions_2_test, target_names=df_target_grouped_m3.columns))
# Out:
#                        precision    recall  f1-score   support
#
#             oil_equip       0.95      1.00      0.98      3633
# electric_equip_common       1.00      0.95      0.97      3241
#              rotating       0.98      0.92      0.95        86
#                valves       0.99      0.98      0.99      2762
#         bearings_mech       0.96      0.95      0.96      3380
#          bearing_temp       0.00      0.00      0.00         0
#           static_equp       0.86      0.97      0.91      1900
#               process       0.00      0.00      0.00         0
#     тр-р тм-4000-10/6       0.40      0.97      0.56        30
#
#             micro avg       0.95      0.97      0.96     15032
#             macro avg       0.68      0.75      0.70     15032
#          weighted avg       0.96      0.97      0.96     15032
#           samples avg       0.96      0.97      0.96     15032
# c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
matrixes_res = multilabel_confusion_matrix(df_target_grouped_m3.values, predictions)

for matrix in matrixes_res:
    FP = matrix[0][1]
    FN = matrix[1][0]
    TP = matrix[1][1]
    TN = matrix[0][0]
    
    print(f"{TP / (TP + FN + FP):2f}")
# Out:
# 0.994430
# 0.980727
# 0.908197
# 0.991967
# 0.977569
# nan
# 0.967952
# 1.000000
# 0.884058
# C:\Users\parshin_sa2\AppData\Local\Temp\ipykernel_38688\201100647.py:9: RuntimeWarning: invalid value encountered in longlong_scalars
#   print(f"{TP / (TP + FN + FP):2f}")

# %%
print(classification_report(df_target_grouped_m3.values, predictions_2, target_names=df_target_grouped_m3.columns))
# Out:
#                        precision    recall  f1-score   support
#
#             oil_equip       1.00      0.99      1.00     11484
# electric_equip_common       1.00      0.98      0.99     10412
#              rotating       0.91      1.00      0.95       832
#                valves       1.00      1.00      1.00      9057
#         bearings_mech       0.99      0.98      0.99      8544
#          bearing_temp       0.00      0.00      0.00         0
#           static_equp       0.98      0.99      0.98      6333
#               process       1.00      1.00      1.00         2
#     тр-р тм-4000-10/6       0.89      1.00      0.94       674
#
#             micro avg       0.99      0.99      0.99     47338
#             macro avg       0.86      0.88      0.87     47338
#          weighted avg       0.99      0.99      0.99     47338
#           samples avg       0.98      0.98      0.98     47338
# c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
search_2.fit(df_preproc_features, df_target_grouped_m3)
print("Best params:", search.best_params_)
print("Best score:", search.best_score_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best params: {'preprocessor__imputer__strategy': 'mean', 'classifier__n_estimators': 500, 'classifier__min_samples_leaf': 10, 'classifier__max_depth': 20, 'classifier__class_weight': 'balanced'}
# Best score: 0.13451600462784422

# %% [markdown]
# ----

# %%
from sklearn.utils._bunch import Bunch as sklearn_bunch
from matplotlib.figure import Figure as mpl_figure

def plot_vert_boxplot(permutation_res: sklearn_bunch,
                      columns: np.ndarray,
                      whiskers_len: float = 10,
                      figsize: tuple = (20, 10),
                      ) -> mpl_figure:
    """
    Plot vertical boxplot in descending format first of all for permutation_importance

    Args:
        permutation_res (sklearn_bunch): results of permutation_importance in 
        dict-alike format
        columns (np.ndarray): column names to set them for the plot
        whiskers_len (float, optional): len to detect outliers in the formula 
        Q1 - / Q3 + whis*(Q3-Q1). Defaults to 10 - no visible outliers.
        figsize (tuple, optional): size of the plot. Defaults to (20, 10).

    Returns:
        mpl_figure: matplotlib figure to save
    """
    sorted_importances_idx = permutation_res.importances_mean.argsort()
    importances = pd.DataFrame(
        permutation_res.importances[sorted_importances_idx].T,
        columns=columns[sorted_importances_idx],
    )
    ax = importances.plot.box(vert=False, whis=whiskers_len, figsize=figsize)
    ax.set_title("Permutation Importances (test set)")
    ax.axvline(x=0, color="k", linestyle="--")
    ax.set_xlabel("Decrease in accuracy score")
    ax.figure.tight_layout()
    return ax

# %%
importance_results = {key: [] for key in df_target_grouped_m3.columns}

importance_res_class = permutation_importance(clf_3, X_test, y_test, n_repeats=10, random_state=SEED)
# importance_res_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[297], line 3
#       1 importance_results = {key: [] for key in df_target_grouped_m3.columns}
# ----> 3 importance_res_class = permutation_importance(clf_3, X_test, y_test, n_repeats=10, random_state=SEED)
#       4 # importance_res_
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\inspection\_permutation_importance.py:289, in permutation_importance(estimator, X, y, scoring, n_repeats, n_jobs, random_state, sample_weight, max_samples)
#     285     scorer = _MultimetricScorer(scorers=scorers_dict)
#     287 baseline_score = _weights_scorer(scorer, estimator, X, y, sample_weight)
# --> 289 scores = Parallel(n_jobs=n_jobs)(
#     290     delayed(_calculate_permutation_scores)(
#     291         estimator,
#     292         X,
#     293         y,
#     294         sample_weight,
#     295         col_idx,
#     296         random_seed,
#     297         n_repeats,
#     298         scorer,
#     299         max_samples,
#     300     )
#     301     for col_idx in range(X.shape[1])
#     302 )
#     304 if isinstance(baseline_score, dict):
#     305     return {
#     306         name: _create_importances_bunch(
#     307             baseline_score[name],
#    (...)
#     311         for name in baseline_score
#     312     }
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\joblib\parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\joblib\parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\inspection\_permutation_importance.py:70, in _calculate_permutation_scores(estimator, X, y, sample_weight, col_idx, random_state, n_repeats, scorer, max_samples)
#      68     else:
#      69         X_permuted[:, col_idx] = X_permuted[shuffling_idx, col_idx]
# ---> 70     scores.append(_weights_scorer(scorer, estimator, X_permuted, y, sample_weight))
#      72 if isinstance(scores[0], dict):
#      73     scores = _aggregate_score_dicts(scores)
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\inspection\_permutation_importance.py:25, in _weights_scorer(scorer, estimator, X, y, sample_weight)
#      23 if sample_weight is not None:
#      24     return scorer(estimator, X, y, sample_weight=sample_weight)
# ---> 25 return scorer(estimator, X, y)
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\metrics\_scorer.py:527, in _PassthroughScorer.__call__(self, estimator, *args, **kwargs)
#     525 def __call__(self, estimator, *args, **kwargs):
#     526     """Method that wraps estimator.score"""
# --> 527     return estimator.score(*args, **kwargs)
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\pipeline.py:756, in Pipeline.score(self, X, y, sample_weight)
#     754 Xt = X
#     755 for _, name, transform in self._iter(with_final=False):
# --> 756     Xt = transform.transform(Xt)
#     757 score_params = {}
#     758 if sample_weight is not None:
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\pipeline.py:696, in Pipeline.transform(self, X)
#     694 Xt = X
#     695 for _, _, transform in self._iter():
# --> 696     Xt = transform.transform(Xt)
#     697 return Xt
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\utils\_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\impute\_base.py:530, in SimpleImputer.transform(self, X)
#     515 """Impute all missing values in `X`.
#     516
#     517 Parameters
#    (...)
#     526     `X` with imputed values.
#     527 """
#     528 check_is_fitted(self)
# --> 530 X = self._validate_input(X, in_fit=False)
#     531 statistics = self.statistics_
#     533 if X.shape[1] != statistics.shape[0]:
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\impute\_base.py:315, in SimpleImputer._validate_input(self, X, in_fit)
#     312     force_all_finite = True
#     314 try:
# --> 315     X = self._validate_data(
#     316         X,
#     317         reset=in_fit,
#     318         accept_sparse="csc",
#     319         dtype=dtype,
#     320         force_all_finite=force_all_finite,
#     321         copy=self.copy,
#     322     )
#     323 except ValueError as ve:
#     324     if "could not convert" in str(ve):
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\base.py:605, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     603         out = X, y
#     604 elif not no_val_X and no_val_y:
# --> 605     out = check_array(X, input_name="X", **check_params)
#     606 elif no_val_X and not no_val_y:
#     607     out = _check_y(y, **check_params)
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\utils\validation.py:915, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     913         array = xp.astype(array, dtype, copy=False)
#     914     else:
# --> 915         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     916 except ComplexWarning as complex_warning:
#     917     raise ValueError(
#     918         "Complex data not supported\n{}\n".format(array)
#     919     ) from complex_warning
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\utils\_array_api.py:384, in _asarray_with_order(array, dtype, order, copy, xp)
#     380         array = numpy.asarray(array, order=order, dtype=dtype)
#     382     # At this point array is a NumPy ndarray. We convert it to an array
#     383     # container that is consistent with the input's namespace.
# --> 384     return xp.asarray(array)
#     385 else:
#     386     return xp.asarray(array, dtype=dtype, copy=copy)
#
# File c:\Users\parshin_sa2\Miniconda3\envs\pm-rotating-equip\lib\site-packages\sklearn\utils\_array_api.py:247, in _NumPyAPIWrapper.asarray(self, x, dtype, device, copy)
#     243 def astype(self, x, dtype, *, copy=True, casting="unsafe"):
#     244     # astype is not defined in the top level NumPy namespace
#     245     return x.astype(dtype, copy=copy, casting=casting)
# --> 247 def asarray(self, x, *, dtype=None, device=None, copy=None):  # noqa
#     248     _check_device_cpu(device)
#     249     # Support copy in NumPy namespace
#
# KeyboardInterrupt:

# %%
for key in importance_res:
    importance_res[key] = importance_res[key][clf_3['feature_selector'].get_support()]

# %%
importance_boxplot = plot_vert_boxplot(importance_res,
                                       selected_features,
                                       10,
                                       (20, 20))
